# %% [markdown]
# # Module 4 Final Project
# - __Student:__ Patrick Routh
# <br>
# - __Cohort:__ Part-Time January 2019
# <br>
# - __Instructor:__ Brandon Lewis
# <br>
# - __Due:__ September, 2019
# <br>
# - __Blog Post URL:__ https://rickrouth12.github.io/choosing_the_right_activation_function_for_your_artificial_neural_network

# %% [markdown]
# ## Introduction

# %% [markdown]
# As the number of Internet of Things (IoT) devices deployed dramatically increases worldwide, and the
# traffic volume of IoT-based DDoS attacks reaches unprecedented levels, the need for timely detection of
# IoT botnet attacks has become imperative for mitigating the risks associated with these attacks. Instantaneous detection promotes network security, as it expedites the alerting and disconnection of compromised IoT devices from the network, thus stopping the botnet from propagating and preventing further outbound attack traffic.
#
# ### Datasets
# Detection of IoT Botnet Attacks N-BaIoT Data Set
# <br>
# <br>
# IoT Devices:
# 1. Provision PT 737E Wi-Fi Security Camera
# 2. Provision PT 838 Outdoor Wi-Fi Security Camera
# 3. SimpleHome XCS7-1002 WHT Security Camera
# 4. SimpleHome XCS7-1003 WHT Security Camera
# 5. Philips B120N/10 Wireless Baby Monitor
# 6. Ecobee SmartThermostat with Voice Control
# 7. Ennio CT8501A12 Video Intercom Doorbell
# 8. Danmini Wi-Fi Video Doorbell

# %% [markdown]
# #### Link:
# https://archive.ics.uci.edu/ml/datasets/detection_of_IoT_botnet_attacks_N_BaIoT
# <br>
# #### Dataset Creators:
# Yair Meidan, Michael Bohadana, Yael Mathov, Yisroel Mirsky, Dominik Breitenbacher, Asaf Shabtai and Yuval Elovici
# <br>
# #### Citation:
# Y. Meidan, M. Bohadana, Y. Mathov, Y. Mirsky, D. Breitenbacher, A. Shabtai, and Y. Elovici 'N-BaIoT: Network-based Detection of IoT Botnet Attacks Using Deep Autoencoders', IEEE Pervasive Computing, Special Issue - Securing the IoT (July/Sep 2018)
# <br>
# #### Description:
# This dataset consists of over 7 million records of network traffic gathered from 9 commercial IoT lab-hosted devices authentically infected by two advanced IoT botnets, Mirai and Bashlite.
# <br>
# #### Abstract:
# The proliferation of IoT devices which can be more easily compromised than desktop computers has led to an increase in the occurrence of IoT-based botnet attacks. In order to mitigate this new threat there is a need to develop new methods for detecting attacks launched from compromised IoT devices and differentiate between hour and millisecond long IoT-based attacks. In this project, I aim to create artificial neural networks to accurately detect anomalous network traffic emanating from compromised IoT devices. The chosen dataset provides the required generated data from nine infected commercial IoT devices in a lab with two of the most widely known IoT-based botnets, Mirai and BASHLITE. The evaluation results demonstrate a proposed method to accurately detect attacks as they are  launched from compromised IoT devices in a botnet.
#
# Botnets such as Mirai and BASHLITE are typically constructed in several distinct operational steps:
# 1. Propagation
# 2. Infection
# 3. C&C communication (command and control)
# 4. Execution of attacks
#
# Unlike most previous studies on botnet detection, which addressed the early operational steps, I will focus on the last step, execution of attacks.
#
# ### Background
#
# #### What is a Botnet?
# A botnet refers to a group of computers which have been infected by malware and have come under the control of a malicious actor. The term botnet is a portmanteau from the words robot and network and each infected device is called a bot. Botnets can be designed to accomplish illegal or malicious tasks including sending spam, stealing data, ransomware, fraudulently clicking on ads or distributed denial-of-service (DDoS) attacks.
#
# #### What is a distributed denial-of-service attack?
# Distributed denial-of-service (DDoS) attacks are digital sieges in which an attacker causes thousands of hacked systems to hit a target with so much junk traffic that it falls over and remains unreachable by legitimate visitors. While DDoS attacks typically target a single Web site or Internet host, they often result in widespread collateral Internet disruption. Botnets like Mirai and Bashlite are used to knock individuals, businesses, governmental agencies, and non-profits offline on a daily basis.
#
# #### How does an attack affect an infected device?
# While some malware, such as ransomware, will have a direct impact on the owner of the device, DDoS botnet malware can have different levels of visibility; some malware is designed to take total control of a device, while other malware runs silently as a background process while waiting silently for instructions from the attacker or “bot herder.”
#
# #### How do botnets form?
# Self-propagating botnets recruit additional bots through a variety of different channels. Pathways for infection include the exploitation of website vulnerabilities, Trojan horse malware, and cracking weak authentication to gain remote access. Once access has been obtained, all of these methods for infection result in the installation of malware on the target device, allowing remote control by the operator of the botnet. Once a device is infected, it may attempt to self-propagate the botnet malware by recruiting other hardware devices in the surrounding network.
#
# While it's infeasible to pinpoint the exact numbers of bots in a particular botnet, estimations for total number of bots in a sophisticated botnet have ranged in size from a few thousand to greater than a million.
#
# #### Why are IoT devices prime targets for botnets?
# These devices, ranging from home routers to security cameras to baby monitors, often include an embedded, stripped down Linux system. They also often have no built-in ability to be patched remotely and are in physically remote or inaccessible locations.
#
# #### Analyzing the Mirai Botnet
# Mirai took advantage of insecure IoT devices in a simple but clever way. Rather than attempting to use complex wizardry to track down IoT gadgets, it scanned big blocks of the internet for open Telnet ports, then attempted to log in using 61 username/password combos that are frequently used as the default for these devices and never changed. In this way, it was able to amass an army of compromised closed-circuit TV cameras and routers, ready to do its bidding.<br>
#
# - Mirai can launch both HTTP flood and network-level attacks
# - There are certain IP address ranges that Mirai is hard-wired to avoid, including those owned by GE, Hewlett-Packard, and the U.S. Department of Defense
# - Upon infecting a device, Mirai looks for other malware on that device and wipes it out, in order to claim the gadget as its own
# - Mirai's code contains a few Russian-language strings—which, as we later learned, were a red herring about its ultimate origins
#
# #### Anayzing the Bashlite Botnet
# Bashlite is malware which infects Linux systems in order to launch DDoS attacks. The original version in 2014 exploited a flaw in the bash shell to exploit devices running BusyBox. A few months later, a variant was detected that could also infect other vulnerable devices in the local network. In 2015, its source code was leaked, causing a proliferation of different variants and the infection of over 1 million devices. Of the identifiable devices participating in these botnets in August 2016, almost 96% were IoT devices (95% of those were cameras and DVRs, 4% were home routers, and 1% were compromised Linux servers). A larger percentage of the 1 million infected devies were located in Taiwain, Brazil, and Colombia.
# <br>
# It propagates via brute forcing, using a built-in dictionary of common usernames and passwords. The Bashlite malware connects to random IP addresses and attempts to login, with successful logins reported back to the command and control server.
# <br>
# The researchers noted that this distribution represents a large shift in the composition of botnets, compared to the traditional DDoS botnet models based on compromised servers and home routers. The actual DDoS attacks are simple UDP and TCP floods. High-bandwidth attacks are more often used in UDP floods, while high packets-per-second attacks are typically used for TCP floods. Most of the detected attacks were short-lived. The median duration was just over two minutes, and 75 percent of the attacks timed out shorter than five minutes.
#
# #### Sources
# <a href="https://www.cloudflare.com/learning/ddos/what-is-a-ddos-botnet/">CloudFlare - What is a DDoS Botnet?</a>
# <br>
# <a href="https://www.csoonline.com/article/3258748/the-mirai-botnet-explained-how-teen-scammers-and-cctv-cameras-almost-brought-down-the-internet.html">The Mirai Botnet Explained - How teen scammers and CCTV Cameras Almost Brought Down the Internet</a>
# <br>
# <a href="https://malware.wikia.org/wiki/BASHLITE">Malware Wiki - BASHLITE</a>
# <br>
# <a href="https://securityintelligence.com/news/bashlite-malware-uses-iot-for-ddos-attacks/">Security Intelligence - Bashlite Malware Uses IoT for DDoS Attacks</a>

# %%
from IPython.display import Image
Image("Kaspersky-Lab-Inforgaphic-Botnet.jpeg", width=600)

# %%
from IPython.display import Image
Image("OWASP_IoT_top_10_risks.jpeg", width=600)

# %% [markdown]
# ## Question -  Can we detect botnet attacks on IoT devices in real-time to automatically trigger a response to mitigate their potential deleterious impacts?

# %% [markdown]
# ### Approach

# %% [markdown]
# ### The OSEMN Framework
# I will be leveraging the OSEMN Framework to attack this project. OSEMN stands for Obtain, Scrub, Explore, Model, and iNterpret.
# <br>
# 1. __Obtain__ - understanding stakeholder requirements, gathering information on the problem, and finally sourcing data that we think will be necessary for solving this problem
# 2. __Scrub__ - preprocessing our data, identifying and removing null values, dealing with outliers, normalizing data, and feature engineering/feature selection
# 3. __Explore__ - getting to know the dataset you're working with, create visualizations, understanding the distribution of different columns, checking for multicollinearity, check the balance of the classes in the dataset
# 4. __Model__ - building and tuning models, defining a theshold for success, selecting machine learning algorithms to test on the project, and tuning the ones that show promise to try and increase your results
# 5. __Interpret__ - interpret the results of your models, communicate results to stakeholders, determine if more invesitgation is needed or different data

# %% [markdown]
# # Obtaining the Data

# %% [markdown]
# __Import Libraries__

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(0)
import matplotlib.pyplot as plt
# %matplotlib inline
import keras
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Input, Dense, LSTM, Embedding
from keras.layers import Dropout, Activation, Bidirectional, GlobalMaxPool1D
from keras.models import Model
from keras import initializers, regularizers, constraints, optimizers, layers
from keras.preprocessing import text, sequence
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras import models
from keras import layers
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, auc, roc_curve, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.
# /Users/patrickrouth/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %% [markdown]
# ## Internet of Things Devices

# %% [markdown]
# ### Provision PT 737E Security Camera
# Provision-ISR advanced Plug & View cameras are ideal for monitoring your home, office or business at both day & night.
# - 1 Mega-Pixel camera
# - Wide angle - 3.6mm lens
#     - Pan range: 280°
#     - Tilt range: 80°
# - Advanced H.264 Compression
# - 2 Way Audio with Built-in Speaker/Microphone
#     - Local recording on Micro SD
# - Wireless support (802.11b/g/n)
# - Motion detection
# - iPhone/iPad/Android mobile viewer app
#     - Live view
#     - Gesture Control
#     - Remote playback
#     - Local SnapShot/video recording

# %%
provision_benign_1 = pd.read_csv("Provision_737E_camera_mirai_attacks/benign_traffic.csv")
provision_mirai_ack_1 = pd.read_csv("Provision_737E_camera_mirai_attacks/ack.csv")
provision_mirai_scan_1 = pd.read_csv("Provision_737E_camera_mirai_attacks/scan.csv")

# %%
provision_bashlite_scan = pd.read_csv("Provision_737E_camera_bashlite_attacks/scan.csv")
provision_bashlite_junk = pd.read_csv("Provision_737E_camera_bashlite_attacks/junk.csv")
provision_bashlite_tcp = pd.read_csv("Provision_737E_camera_bashlite_attacks/tcp.csv")
provision_bashlite_udp = pd.read_csv("Provision_737E_camera_bashlite_attacks/udp.csv")
provision_bashlite_combo = pd.read_csv("Provision_737E_camera_bashlite_attacks/combo.csv")

# %% [markdown]
# ### Provision 838 Security Camera
# Provision-ISR advanced Plug & View cameras are ideal for monitoring your home, office or business at both day & night.
# - 2 Mega-Pixel camera
# - Wide angle- 3.6mm lens
#     - Pan range: 355°
#     - Tilt range: 120°
# - Advanced H.264 Compression
# - 2 Way Audio with Built-in Speaker/Microphone
# - Local recording on Micro SD
# - Wireless support (802.11b/g/n)
# - Motion detection
# - iPhone/iPad/Android mobile viewer app
#     - Live view
#     - Gesture Control
#     - Remote playback
#     - Local SnapShot/video recording

# %%
provision_838_benign_1 = pd.read_csv("Provision_838_mirai_attacks/benign_traffic.csv")
provision_838_mirai_ack_1 = pd.read_csv("Provision_838_mirai_attacks/ack.csv")
provision_838_mirai_scan_1 = pd.read_csv("Provision_838_mirai_attacks/scan.csv")

# %%
provision_838_bashlite_scan = pd.read_csv("Provision_838_bashlite_attacks/scan.csv")
provision_838_bashlite_junk = pd.read_csv("Provision_838_bashlite_attacks/junk.csv")
provision_838_bashlite_tcp = pd.read_csv("Provision_838_bashlite_attacks/tcp.csv")
provision_838_bashlite_udp = pd.read_csv("Provision_838_bashlite_attacks/udp.csv")
provision_838_bashlite_combo = pd.read_csv("Provision_838_bashlite_attacks/combo.csv")

# %% [markdown]
# ### Ecobee SmartThermostat
# The ecobee4 is ecobee's flagship product. It is a touchscreen smart thermostat that works with up to 32 remote temperature/motion sensors to adjust the thermostat based on where you are. The thermostats are controlled by using the built-in touchscreen, using a registered login or using a companion app available for iOS, Android and the Apple Watch
# - IFTTT integration

# %%
ecobee_thermostat_benign = pd.read_csv("Ecobee_thermostat_mirai/benign_traffic.csv")
ecobee_thermostat_mirai_ack_1 = pd.read_csv("Ecobee_thermostat_mirai/ack.csv")
ecobee_thermostat_mirai_scan_1 = pd.read_csv("Ecobee_thermostat_mirai/scan.csv")
ecobee_thermostat_bashlite_scan = pd.read_csv("Ecobee_thermostat_bashlite/scan.csv")
ecobee_thermostat_bashlite_junk = pd.read_csv("Ecobee_thermostat_bashlite/junk.csv")
ecobee_thermostat_bashlite_tcp = pd.read_csv("Ecobee_thermostat_bashlite/tcp.csv")
ecobee_thermostat_bashlite_udp = pd.read_csv("Ecobee_thermostat_bashlite/udp.csv")
ecobee_thermostat_bashlite_combo = pd.read_csv("Ecobee_thermostat_bashlite/combo.csv")

# %% [markdown]
# ### Philips Baby Monitor
# Philips Baby monitors secure private connections to your baby with DECT technology that guarantees zero interference, clear souund, with range up to 900 feet. Comfort your little one with the talkback feature, a night light or lullabies, while monitoring the temperature in the room
# - Parent unit is outlet or battery powered
# - Talk back feature to stay connected
# - Range up to 330 meters. Charging time: 10 hours
# - Zero interference and private connection: DECT technology guarantees zero interference and 100% privacy
# - Customized temperature sensor
# - Night light and lullabies

# %%
philips_baby_monitor_benign = pd.read_csv("Philips_baby_monitor_mirai/benign_traffic.csv")
philips_baby_monitor_mirai_ack_1 = pd.read_csv("Philips_baby_monitor_mirai/ack.csv")
philips_baby_monitor_mirai_scan_1 = pd.read_csv("Philips_baby_monitor_mirai/scan.csv")
philips_baby_monitor_bashlite_scan = pd.read_csv("Philips_baby_monitor_bashlite/scan.csv")
philips_baby_monitor_bashlite_junk = pd.read_csv("Philips_baby_monitor_bashlite/junk.csv")
philips_baby_monitor_bashlite_tcp = pd.read_csv("Philips_baby_monitor_bashlite/tcp.csv")
philips_baby_monitor_bashlite_udp = pd.read_csv("Philips_baby_monitor_bashlite/udp.csv")
philips_baby_monitor_bashlite_combo = pd.read_csv("Philips_baby_monitor_bashlite/combo.csv")

# %% [markdown]
# ### SimpleHome 1002 Wi-Fi Security Camera
# Record audio and video at 720 HD quality with panoramic and tilt options. Easily use your smart devices’ touchscreen to position your security camera.
#
# - Allows panoramic viewing (355°) and tilt (120°) for optimal viewing coverage
# - Has a 2 way talk feature which enables you to talk back to anyone in the room
# - Can be set to always record or to start recording when motion is detected
# - Infrared allows recording at night and records at 720 HD quality
# - Supports Micro SD card (not included)
# - Records in segments with automatic recycling
# - No hub required, works off your existing Wi-Fi network

# %%
simple_home_benign = pd.read_csv("SimpleHome_1002_mirai_attacks/benign_traffic.csv")
simple_home_mirai_ack_1 = pd.read_csv("SimpleHome_1002_mirai_attacks/ack.csv")
simple_home_mirai_scan_1 = pd.read_csv("SimpleHome_1002_mirai_attacks/scan.csv")

simple_home_bashlite_scan = pd.read_csv("SimpleHome_1002_bashlite_attacks/scan.csv")
simple_home_bashlite_junk = pd.read_csv("SimpleHome_1002_bashlite_attacks/junk.csv")
simple_home_bashlite_tcp = pd.read_csv("SimpleHome_1002_bashlite_attacks/tcp.csv")
simple_home_bashlite_udp = pd.read_csv("SimpleHome_1002_bashlite_attacks/udp.csv")
simple_home_bashlite_combo = pd.read_csv("SimpleHome_1002_bashlite_attacks/combo.csv")

# %% [markdown]
# ### Simple Home 1003 Outdoor Wi-Fi Security Camera
# Weatherproof outdoor camera can withstand rain, snow, dust, and wind. Keep your home safe and secure inside and out. Can be set to record 24/7 or just when motion is detected.
#
# - Control, stream, and playback videos via app from anywhere
# - Records video at 720 HD quality and 107° field of view
# - IP-65 weatherproof, protects against wind, rain, dust, and snow
# - Infrared for night time use
# - Records in segments w/ automatic recycling & built in 8GB Memory
# - Includes wall plug adapter and 5ft cord (Camera must be plugged in at all times)
# - No hub required, works off your existing Wi-Fi network

# %%
simple_home_1003_benign = pd.read_csv("Simple_home_1003_mirai_attacks/benign_traffic.csv")
simple_home_1003_mirai_ack_1 = pd.read_csv("Simple_home_1003_mirai_attacks/ack.csv")
simple_home_1003_mirai_scan_1 = pd.read_csv("Simple_home_1003_mirai_attacks/scan.csv")
simple_home_1003_bashlite_scan = pd.read_csv("Simple_home_1003_bashlite_attacks/scan.csv")
simple_home_1003_bashlite_junk = pd.read_csv("Simple_home_1003_bashlite_attacks/junk.csv")
simple_home_1003_bashlite_tcp = pd.read_csv("Simple_home_1003_bashlite_attacks/tcp.csv")
simple_home_1003_bashlite_udp = pd.read_csv("Simple_home_1003_bashlite_attacks/udp.csv")
simple_home_1003_bashlite_combo = pd.read_csv("Simple_home_1003_bashlite_attacks/combo.csv")

# %% [markdown]
# ### Danmini Doorbell
# Doorbell WIFI doorbell guards the last line of home security. Safely use it under the premise of no destroying the existing door structure, no drilling, no wiring. The product is equipped with a 720P camera, clear night vision, and mobile phone remote view.
# - 3 million pixel camera, HD F2.0 wide aperture lens, in low light environment, image is still clear
# - Horizontal 145 degree wide viewing angle
# - Supports WIFI wireless connection and wired connect
# - PIR motion detection video / real-time video / APP manual video
# - Adjusts or self adaption multiple resolutions 1280 x 720 / 640 x 360 / 320 x 180
# - Real-time video or audio intercom with visitors
# - Built-in echo elimination circuit to get better voice quality
# - Built-in 4pcs infrared night vision light, coordinate with IR CUT technology, it works no matter daytime or night
# - Relay signal output, controls electronic lock to realize remote unlocking
# - Supports TF card (not included) and mobile terminal storage (max supports 64G TF card)
# - Supports taking pictures and video recording
# - Supports remote unlock

# %%
danmini_doorbell_benign = pd.read_csv("Danmini_doorbell_mirai/benign_traffic.csv")
danmini_doorbell_mirai_ack_1 = pd.read_csv("Danmini_doorbell_mirai/ack.csv")
danmini_doorbell_mirai_scan_1 = pd.read_csv("Danmini_doorbell_mirai/scan.csv")

danmini_doorbell_bashlite_scan = pd.read_csv("Danmini_doorbell_bashlite/scan.csv")
danmini_doorbell_bashlite_junk = pd.read_csv("Danmini_doorbell_bashlite/junk.csv")
danmini_doorbell_bashlite_tcp = pd.read_csv("Danmini_doorbell_bashlite/tcp.csv")
danmini_doorbell_bashlite_udp = pd.read_csv("Danmini_doorbell_bashlite/udp.csv")
danmini_doorbell_bashlite_combo = pd.read_csv("Danmini_doorbell_bashlite/combo.csv")

# %% [markdown]
# ### Ennio Doorbell
# WiFi video doorbell connects to network via wireless router or network cable. Mobile devices include smartphone or tablet, could connect to the doorbell. After the visitor rings, mobile devices could interact with doorbell via real time video and audio, user can view the visitor, then decide to whether intercom or open the door etc. WiFi doorbell support PIR and motion detection alarm, with IR night vision, 12V power supply. 2.4G Wifi, real time viewing, max to support 100M broadband, support Android and IOS operation system. Multi doorbell and multi mobile device compatibility.
#
# - 7" color TFT LCD without radiation, low power consumption and high definition
# - Outdoor IR Camera with Night Vision, 1/4" CMOS
# - Electric lock-control function
# - Hand-free intercom
# - Mute indoor intercom function
# - Monitoring the outside of the door
# - 16 kinds of door bell rings
# - Volume, brightness and contrast adjustable
# - Easy installation by yourself with adapter and cable we provide in this kit
# - Powered by indoor monitor
#     - Power source: AC100V-240V/50-60Hz

# %%
ennio_doorbell_benign = pd.read_csv("Ennio_doorbell_bashlite/benign_traffic.csv")
ennio_doorbell_bashlite_scan = pd.read_csv("Ennio_doorbell_bashlite/scan.csv")
ennio_doorbell_bashlite_junk = pd.read_csv("Ennio_doorbell_bashlite/junk.csv")
ennio_doorbell_bashlite_tcp = pd.read_csv("Ennio_doorbell_bashlite/tcp.csv")
ennio_doorbell_bashlite_udp = pd.read_csv("Ennio_doorbell_bashlite/udp.csv")
ennio_doorbell_bashlite_combo = pd.read_csv("Ennio_doorbell_bashlite/combo.csv")

# %% [markdown]
# ### Understanding the Features

# %% [markdown]
# Whenever a packet arrives, a behavioral snapshot of the hosts and protocols that communicated this packet is captured. This snapshot obtains the packet’s context by extracting 115 traffic statistics over several temporal windows to summarize all of the traffic that has:
# <br>
# (1) Originated from the same IP in general<br>
# (2) Originated from both the same source MAC and the same IP address<br>
# (3) Sent between the source and destination IPs (channel)<br>
# (4) Sent between the source to destination TCP/UDP sockets (socket)<br>
#
# #### Feature Extraction Values
#
# | Value | Statistic | Aggregated By | Total Number of Features |
# |------|------|------|------|
# | Packet size (of outbound packets only)  | Mean, Variance | Source IP$,^{1}$ Source MAC-IP$,^{2}$ Channel, Socket$,^{3}$ | 8 |
# | Packet count | Number | Source IP, Source MAC-IP, Channel, Socket | 4 |
# | Packet jitter (the amount of time between packet arrivals) | Mean, Variance, Number | Channel | 3 |
# | Packet size (of both inbound and outbound together) | Magnitude, Radius, Covariance, Correlation coefficient | Channel, Socket | 8 |
#
# $^{1}$ The source IP is used to track the host as a whole<br>
# $^{2}$ The source MAC-IP adds the capability to distinguish between traffic originating from different gateways and spoofed IP addresses<br>
# $^{3}$ The sockets are determined by the source and destination TCP or UDP port numbers. For example, all of the traffic sent from
# 192.168.1.12:1234 to 192.168.1.50:80 (traffic flowing from one socket to another).
#
# We extract the same set of 23 features (capturing the above, see Table 2) from five time windows of the most
# recent 100ms, 500ms, 1.5sec, 10sec, and 1min.
#
# - __SourceFrom__ - what kind of message
# - __FileTimeUTC__ -  time the attack happened, but I had to set everything is same
# - __Botnet__ - botnet type
# - __SourceIp__ - source IP of botnet
# - __SourcePort__ - source port of botnet
# - __SourceIpAsnNr__ - local ISP
# - __TargetIp__ - target IP
# - __TargetPort__ - target Port
# - __Payload__ - empty
# - __SourceIpCountryCode__ - country, basically all is Malaysia
# - __SourceIpRegion__ - region code
# - __SourceIpCity__ - region name
# - __SourceIpPostalCode__ - empty
# - __SourceIpLatitude__ - source latitude
# - __SourceIpLongitude__ - source longitude
# - __HttpRequest__ - what kind of request
# - __Threat Confidence__ - botnet impact
#
# #### Stream aggregation:
# - H: Stats summarizing the recent traffic from this packet's host (IP)
# - HH: Stats summarizing the recent traffic going from this packet's host (IP) to the packet's destination host
# - HpHp: Stats summarizing the recent traffic going from this packet's host+port (IP) to the packet's destination host+port<br>Example 192.168.4.2:1242 -> 192.168.4.12:80
# - HH_jit: Stats summarizing the jitter of the traffic going from this packet's host (IP) to the packet's destination host.
#
# #### Time-frame (The decay factor Lambda used in the damped window):
# How much recent history of the stream is captured in these statistics L5, L3, L1, L0.1, L0.01
#
# #### The statistics extracted from the packet stream:
# __weight__: The weight of the stream (can be viewed as the number of items observed in recent history) <br>
# __mean__: the average size packet stream <br>
# __std__: standard deviation of packet stream <br>
# __radius__: The root squared sum of the two streams' variances <br>
# __magnitude__: The root squared sum of the two streams' means <br>
# __cov__: an approximated covariance between two streams <br>
# __pcc__: an approximated covariance between two streams
#
#
# ## Target
# Distinguishing between benign and malicious traffic - "Benign/Attack"

# %% [markdown]
# # Preprocessing - scrubbing our data

# %% [markdown]
# ### Feature Engineering
# <br>
# In order to train neural networks on this network traffic data, we will need to create a target feature based on the type of traffic captured in a snapshot. To do this, we will need to add a new column, "Benign/Attack", with binary values to represent benign or normal IoT device events with a 0 and IoT botnet attack events with a 1. We will need to do this for all 8 devices.

# %% [markdown]
# #### Provision PT 737E Security Camera

# %%
dataframes_1 = [provision_benign_1, provision_mirai_ack_1, provision_mirai_scan_1, provision_bashlite_scan, 
              provision_bashlite_junk, provision_bashlite_tcp, provision_bashlite_udp, provision_bashlite_combo]
provision_737_1 = pd.concat(dataframes_1)

# %%
provision_benign_1['Benign/Attack'] = 0
provision_mirai_ack_1['Benign/Attack'] = 1
provision_mirai_scan_1['Benign/Attack'] = 1
provision_bashlite_scan['Benign/Attack'] = 1
provision_bashlite_junk['Benign/Attack'] = 1
provision_bashlite_tcp['Benign/Attack'] = 1
provision_bashlite_udp['Benign/Attack'] = 1
provision_bashlite_combo['Benign/Attack'] = 1

# %%
dataframes_2 = [provision_benign_1, provision_mirai_ack_1, provision_mirai_scan_1, provision_bashlite_scan, 
              provision_bashlite_junk, provision_bashlite_tcp, provision_bashlite_udp, provision_bashlite_combo]
provision_737_2 = pd.concat(dataframes_2)

# %% [markdown]
# #### Simple Home 1002 Wi-Fi Security Camera

# %%
dataframes_3 = [simple_home_benign, simple_home_mirai_ack_1, simple_home_mirai_scan_1, simple_home_bashlite_scan, 
              simple_home_bashlite_junk, simple_home_bashlite_tcp, simple_home_bashlite_udp, 
                simple_home_bashlite_combo]
simple_home_1002_1 = pd.concat(dataframes_3)

# %%
simple_home_benign['Benign/Attack'] = 0
simple_home_mirai_ack_1['Benign/Attack'] = 1
simple_home_mirai_scan_1['Benign/Attack'] = 1
simple_home_bashlite_scan['Benign/Attack'] = 1
simple_home_bashlite_junk['Benign/Attack'] = 1
simple_home_bashlite_tcp['Benign/Attack'] = 1
simple_home_bashlite_udp['Benign/Attack'] = 1
simple_home_bashlite_combo['Benign/Attack'] = 1

# %%
dataframes_4 = [simple_home_benign, simple_home_mirai_ack_1, simple_home_mirai_scan_1, simple_home_bashlite_scan, 
              simple_home_bashlite_junk, simple_home_bashlite_tcp, simple_home_bashlite_udp, 
                simple_home_bashlite_combo]
simple_home_1002_2 = pd.concat(dataframes_4)

# %% [markdown]
# #### Danmini Doorbell

# %%
dataframes_5 = [danmini_doorbell_benign, danmini_doorbell_mirai_ack_1, danmini_doorbell_mirai_scan_1, 
                danmini_doorbell_bashlite_scan, danmini_doorbell_bashlite_junk, danmini_doorbell_bashlite_tcp, 
                danmini_doorbell_bashlite_udp, danmini_doorbell_bashlite_combo]
danmini_doorbell_features_1 = pd.concat(dataframes_5)

# %%
danmini_doorbell_benign['Benign/Attack'] = 0
danmini_doorbell_mirai_ack_1['Benign/Attack'] = 1
danmini_doorbell_mirai_scan_1['Benign/Attack'] = 1
danmini_doorbell_bashlite_scan['Benign/Attack'] = 1
danmini_doorbell_bashlite_junk['Benign/Attack'] = 1
danmini_doorbell_bashlite_tcp['Benign/Attack'] = 1
danmini_doorbell_bashlite_udp['Benign/Attack'] = 1
danmini_doorbell_bashlite_combo['Benign/Attack'] = 1

# %%
dataframes_6 = [danmini_doorbell_benign, danmini_doorbell_mirai_ack_1, danmini_doorbell_mirai_scan_1, 
                danmini_doorbell_bashlite_scan, danmini_doorbell_bashlite_junk, danmini_doorbell_bashlite_tcp, 
                danmini_doorbell_bashlite_udp, danmini_doorbell_bashlite_combo]
danmini_doorbell_target_2 = pd.concat(dataframes_6)

# %% [markdown]
# #### Ecobee Thermostat

# %%
dataframes_7 = [ecobee_thermostat_benign, ecobee_thermostat_mirai_ack_1, ecobee_thermostat_mirai_scan_1, 
                ecobee_thermostat_bashlite_scan, ecobee_thermostat_bashlite_junk, ecobee_thermostat_bashlite_tcp, 
                ecobee_thermostat_bashlite_udp, ecobee_thermostat_bashlite_combo] 
ecobee_thermostat_1 = pd.concat(dataframes_7)

# %%
ecobee_thermostat_benign['Benign/Attack'] = 0
ecobee_thermostat_mirai_ack_1['Benign/Attack'] = 1
ecobee_thermostat_mirai_scan_1['Benign/Attack'] = 1
ecobee_thermostat_bashlite_scan['Benign/Attack'] = 1
ecobee_thermostat_bashlite_junk['Benign/Attack'] = 1
ecobee_thermostat_bashlite_tcp['Benign/Attack'] = 1
ecobee_thermostat_bashlite_udp['Benign/Attack'] = 1
ecobee_thermostat_bashlite_combo['Benign/Attack'] = 1

# %%
dataframes_8 = [ecobee_thermostat_benign, ecobee_thermostat_mirai_ack_1, ecobee_thermostat_mirai_scan_1, 
                ecobee_thermostat_bashlite_scan, ecobee_thermostat_bashlite_junk, ecobee_thermostat_bashlite_tcp, 
                ecobee_thermostat_bashlite_udp, ecobee_thermostat_bashlite_combo]
ecobee_thermostat_2 = pd.concat(dataframes_8)

# %% [markdown]
# #### Ennio Doorbell

# %%
dataframes_9 = [ennio_doorbell_benign, ennio_doorbell_bashlite_scan, ennio_doorbell_bashlite_junk, 
                ennio_doorbell_bashlite_tcp, ennio_doorbell_bashlite_udp, ennio_doorbell_bashlite_combo]
ennio_doorbell_1 = pd.concat(dataframes_9)

# %%
ennio_doorbell_benign['Benign/Attack'] = 0
ennio_doorbell_bashlite_scan['Benign/Attack'] = 1
ennio_doorbell_bashlite_junk['Benign/Attack'] = 1
ennio_doorbell_bashlite_tcp['Benign/Attack'] = 1
ennio_doorbell_bashlite_udp['Benign/Attack'] = 1
ennio_doorbell_bashlite_combo['Benign/Attack'] = 1

# %%
dataframes_10 = [ennio_doorbell_benign, ennio_doorbell_bashlite_scan, ennio_doorbell_bashlite_junk, 
                 ennio_doorbell_bashlite_tcp, ennio_doorbell_bashlite_udp, ennio_doorbell_bashlite_combo]
ennio_doorbell_target_2 = pd.concat(dataframes_10)

# %% [markdown]
# #### Philips Baby Monitor

# %%
dataframes_11 = [philips_baby_monitor_benign, philips_baby_monitor_bashlite_scan, 
                 philips_baby_monitor_bashlite_junk, philips_baby_monitor_bashlite_tcp, 
              philips_baby_monitor_bashlite_udp, philips_baby_monitor_bashlite_combo]
philips_baby_monitor_1 = pd.concat(dataframes_11)

# %%
philips_baby_monitor_benign['Benign/Attack'] = 0
philips_baby_monitor_bashlite_scan['Benign/Attack'] = 1
philips_baby_monitor_bashlite_junk['Benign/Attack'] = 1
philips_baby_monitor_bashlite_tcp['Benign/Attack'] = 1
philips_baby_monitor_bashlite_udp['Benign/Attack'] = 1
philips_baby_monitor_bashlite_combo['Benign/Attack'] = 1

# %%
dataframes_12 = [philips_baby_monitor_benign, philips_baby_monitor_bashlite_scan, 
                 philips_baby_monitor_bashlite_junk, philips_baby_monitor_bashlite_tcp, 
              philips_baby_monitor_bashlite_udp, philips_baby_monitor_bashlite_combo]
philips_baby_monitor_target_2 = pd.concat(dataframes_12)

# %% [markdown]
# #### Provision PT 838 Security Camera

# %%
dataframes_13 = [provision_838_benign_1, provision_838_mirai_ack_1, provision_838_mirai_scan_1, 
                 provision_838_bashlite_scan, provision_838_bashlite_junk, provision_838_bashlite_tcp, 
                 provision_838_bashlite_udp, provision_838_bashlite_combo]
provision_838_1 = pd.concat(dataframes_13)

# %%
provision_838_benign_1['Benign/Attack'] = 0
provision_838_mirai_ack_1['Benign/Attack'] = 1
provision_838_mirai_scan_1['Benign/Attack'] = 1
provision_838_bashlite_scan['Benign/Attack'] = 1
provision_838_bashlite_junk['Benign/Attack'] = 1
provision_838_bashlite_tcp['Benign/Attack'] = 1
provision_838_bashlite_udp['Benign/Attack'] = 1
provision_838_bashlite_combo['Benign/Attack'] = 1

# %%
dataframes_14 = [provision_838_benign_1, provision_838_mirai_ack_1, provision_838_mirai_scan_1, 
                 provision_838_bashlite_scan, provision_838_bashlite_junk, provision_838_bashlite_tcp, 
                 provision_838_bashlite_udp, provision_838_bashlite_combo]
provision_838_2 = pd.concat(dataframes_14)

# %% [markdown]
# #### Simple Home 1003 Security Camera

# %%
dataframes_15 = [simple_home_1003_benign, simple_home_1003_mirai_ack_1, simple_home_1003_mirai_scan_1, 
                 simple_home_1003_bashlite_scan, simple_home_1003_bashlite_junk, simple_home_1003_bashlite_tcp, 
                 simple_home_1003_bashlite_udp, simple_home_1003_bashlite_combo]
simple_home_1003_1 = pd.concat(dataframes_15)

# %%
simple_home_1003_benign['Benign/Attack'] = 0
simple_home_1003_mirai_ack_1['Benign/Attack'] = 1
simple_home_1003_mirai_scan_1['Benign/Attack'] = 1
simple_home_1003_bashlite_scan['Benign/Attack'] = 1
simple_home_1003_bashlite_junk['Benign/Attack'] = 1
simple_home_1003_bashlite_tcp['Benign/Attack'] = 1
simple_home_1003_bashlite_udp['Benign/Attack'] = 1
simple_home_1003_bashlite_combo['Benign/Attack'] = 1

# %%
dataframes_16 = [simple_home_1003_benign, simple_home_1003_mirai_ack_1, simple_home_1003_mirai_scan_1, 
                 simple_home_1003_bashlite_scan, simple_home_1003_bashlite_junk, simple_home_1003_bashlite_tcp, 
                 simple_home_1003_bashlite_udp, simple_home_1003_bashlite_combo]
simple_home_1003_2 = pd.concat(dataframes_16)

# %% [markdown]
# # Exploring our Data

# %% [markdown]
# ### Overview of the Data
# <br>
# 23 features x 5 time intervals = 115 columns - all numerial floats
#
# |Device|Number of Observations|Types of Events|
# |------|-------|------|
# |Provision PT 737E Security Camera| 549,585 entries | Benign traffic, Mirai Ack/Scan, Bashlite Scan, Junk, TCP, UDP, Combo|
# |Provision PT 838 Security Camera| 562,647 entries | Benign traffic, Mirai Ack/Scan, Bashlite Scan, Junk, TCP, UDP, Combo|
# |SimpleHome 1002 Wi-Fi Security Camera| 507,218 entries | Benign traffic, Mirai Ack/Scan, Bashlite Scan, Junk, TCP, UDP, Combo|
# |SimpleHome 1003 Outdoor Wi-Fi Security Camera| 486,827 entries | Benign traffic, Mirai Ack/Scan, Bashlite Scan, Junk, TCP, UDP, Combo|
# |Danmini Doorbell| 576,078 entries | Benign traffic, Mirai Ack/Scan, Bashlite Scan, Junk, TCP, UDP, Combo|
# |Ennio Doorbell| 480,220 entries | Benign traffic, Bashlite Scan, Junk, TCP, UDP, Combo|
# |Philips Baby Monitor| 487,963 entries | Benign traffic, Mirai Ack/Scan, Bashlite Scan, Junk, TCP, UDP, Combo|
# |Ecobee SmartThermostat| 480,220 entries | Benign traffic, Mirai Ack/Scan, Bashlite Scan, Junk, TCP, UDP, Combo|
#
#
#
# There are no changes required to the data types for the numerical and categorical features.

# %%
# Provision PT 737E Wi-Fi Security Camera

provision_737_1.hist(figsize=(40,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a87c0da58>,
# ...
#       dtype=object)

# %%
provision_737_1.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count     549585.000000   549585.000000       549585.000000     549585.000000
# mean          52.682373       97.389107         6158.118108         80.511421
# std           63.668639       97.333855        17103.824294        101.097564
# min            1.000000       60.000000            0.000000          1.000000
# 25%            1.000000       60.000000            0.000000          1.000000
# 50%           18.484697       60.015183            0.039837         31.273022
# 75%           94.148803       74.079202            2.898136        128.910737
# max          304.382099      886.166851       410576.913200        407.906734
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count   549585.000000       549585.000000     549585.000000   549585.000000
# mean        97.411241         6787.143404        218.130080       97.468345
# ...

# %%
provision_737_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 549585 entries, 0 to 61379
# Columns: 115 entries, MI_dir_L5_weight to HpHp_L0.01_pcc
# dtypes: float64(115)
# memory usage: 486.4 MB

# %%
l = provision_737_1.columns.values
number_of_columns=115
number_of_rows = len(l)-1/number_of_columns
plt.figure(figsize=(200,200))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.set_style('whitegrid')
    sns.boxplot(provision_737_1[l[i]],color='green',orient='v')
    plt.tight_layout()

# %%
plt.figure(figsize=(2*number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.distplot(df[l[i]],kde=True)

# %% [markdown]
# ### Scale and Range
# <br>
# We can see from the above distributions that some of the features display significant ranges between the minimum and maximum values recorded. This deviation is also not consistent throughout our 115 features. In order to reduce the impact of significant differences in scale between features, we will need to introduce a data transformation technique - like Min-Max Scaling.

# %% [markdown]
# ### Discovering and Addressing Data Imbalance
# <br>
# In order to address the imbalanced classes (benign and malicious) that we observe in our data sets, we will need to leverage an oversampling strategy to even out the balance and give equal representation to both classes. <br><br>The most common oversampling technique is known as SMOTE: Synthetic Minority Over-sampling TEchnique. <br><br>SMOTE synthesises new minority instances between existing (real) minority instances. SMOTE takes a sample from the dataset, and considers its k nearest neighbors in the feature space. To create a synthetic data point, it takes the vector between one of those k neighbors, and the current data point and multiplies this vector by a random number x (value between 0 and 1). Then it adds this to the current data point to create the new, synthetic data point. It performs this process iteratively on the minority and majority samples until a balanced set of two class samples results.

# %% [markdown]
# # Modeling - Building Deep Neural Networks

# %% [markdown]
# ### Provision PT 737E Security Camera

# %%
x = provision_737_1.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
provision_737_1_scaled= pd.DataFrame(x_scaled)

# %%
X = provision_737_1_scaled
y = provision_737_2["Benign/Attack"].as_matrix().T

# %%
X_resample, y_resample = SMOTE().fit_sample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resample, y_resample, test_size=0.2, random_state=0)

# %%
train_final = X_train[:389944]
label_train_final = y_train[:389944]

val = X_test[97486:]
label_val = y_test[97486:]

print("Train:", np.shape(train_final))
print("Validation:", np.shape(val))
print("Label Validation:", np.shape(label_val))
print("Label Train Final:", np.shape(label_train_final))
# Out:
# Train: (389944, 115)
# Validation: (97487, 115)
# Label Validation: (97487,)
# Label Train Final: (389944,)

# %% [markdown]
# #### Iteration 1 - Scaled Data (MinMax scaling implemented)

# %%
model_provision = models.Sequential()
model_provision.add(layers.Dense(50, activation='relu', input_shape=(115,)))
model_provision.add(layers.Dense(25, activation='relu'))
model_provision.add(layers.Dense(1, activation='sigmoid')) # sigmoidal activation function added for final layer

# %%
model_provision.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model_val = model_provision.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 389944 samples, validate on 97487 samples
# Epoch 1/50
# 389944/389944 [==============================] - 4s 11us/step - loss: 0.1660 - acc: 0.9589 - val_loss: 0.0302 - val_acc: 0.9952
# Epoch 2/50
# 389944/389944 [==============================] - 3s 8us/step - loss: 0.0236 - acc: 0.9953 - val_loss: 0.0194 - val_acc: 0.9957
# Epoch 3/50
# 389944/389944 [==============================] - 3s 7us/step - loss: 0.0182 - acc: 0.9960 - val_loss: 0.0166 - val_acc: 0.9964
# Epoch 4/50
# 389944/389944 [==============================] - 3s 7us/step - loss: 0.0161 - acc: 0.9963 - val_loss: 0.0150 - val_acc: 0.9966
# Epoch 5/50
# 389944/389944 [==============================] - 3s 7us/step - loss: 0.0147 - acc: 0.9966 - val_loss: 0.0137 - val_acc: 0.9969
# Epoch 6/50
# 389944/389944 [==============================] - 2s 6us/step - loss: 0.0135 - acc: 0.9968 - val_loss: 0.0127 - val_acc: 0.9971
# Epoch 7/50
# ...

# %%
pred_train = model_provision.predict(train_final).reshape(-1)
pred_test = model_provision.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.0011297570575182845
# MSE_val: 0.0010902393774343015

# %% [markdown]
# #### Iteration 2 - Regularization techniques - Dropout Layers

# %%
model_provision_2 = models.Sequential()
model_provision_2.add(layers.Dropout(0.3, input_shape=(115,)))
model_provision_2.add(layers.Dense(50, activation='relu'))
model_provision_2.add(layers.Dropout(0.3))
model_provision_2.add(layers.Dense(25, activation='relu'))
model_provision_2.add(layers.Dropout(0.3))
model_provision_2.add(layers.Dense(1, activation='sigmoid'))

model_provision_2.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_val = model_provision_2.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 389944 samples, validate on 97487 samples
# Epoch 1/50
# 389944/389944 [==============================] - 4s 9us/step - loss: 0.2094 - acc: 0.9396 - val_loss: 0.0273 - val_acc: 0.9956
# Epoch 2/50
# 389944/389944 [==============================] - 3s 9us/step - loss: 0.0589 - acc: 0.9882 - val_loss: 0.0195 - val_acc: 0.9968
# Epoch 3/50
# 389944/389944 [==============================] - 3s 9us/step - loss: 0.0439 - acc: 0.9918 - val_loss: 0.0182 - val_acc: 0.9973
# Epoch 4/50
# 389944/389944 [==============================] - 3s 9us/step - loss: 0.0386 - acc: 0.9933 - val_loss: 0.0174 - val_acc: 0.9974
# Epoch 5/50
# 389944/389944 [==============================] - 3s 9us/step - loss: 0.0352 - acc: 0.9940 - val_loss: 0.0168 - val_acc: 0.9974
# Epoch 6/50
# 389944/389944 [==============================] - 3s 9us/step - loss: 0.0317 - acc: 0.9946 - val_loss: 0.0161 - val_acc: 0.9974
# Epoch 7/50
# ...

# %%
pred_train = model_provision_2.predict(train_final).reshape(-1)
pred_test = model_provision_2.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.001152772677260703
# MSE_val: 0.0011200336329848129

# %% [markdown]
# ### Model Performance and Analysis - Provision_PT_737E_Security_Camera

# %% [markdown]
# | Device Name | Iteration 1 Accuracy | Iteration 1 Loss | Iteration 2 Accuracy | Iteration 2 Loss |
# |------|------|------|------|------|
# | Provision 738E Security Camera  | 99.88% | 0.0072  | 99.77%  | 0.0170 |

# %% [markdown]
# ### SimpleHome_XCS7_1002_WHT_Security_Camera

# %% [markdown]
# #### Iteration 1 - Scaled Data (MinMax scaling implemented)

# %%
x = simple_home_1002_1.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
simple_home_1002_1_scaled= pd.DataFrame(x_scaled)

# %%
X = simple_home_1002_1_scaled
y = simple_home_1002_2["Benign/Attack"].as_matrix().T

X_resample, y_resample = SMOTE().fit_sample(X, y)

X_train, X_test, y_train, y_test = train_test_split(X_resample, y_resample, test_size=0.2, random_state=0)

train_final = X_train[:368506]
label_train_final = y_train[:368506]

val = X_test[92127:]
label_val = y_test[92127:]

print("Train:", np.shape(train_final))
print("Validation:", np.shape(val))
print("Label Validation:", np.shape(label_val))
print("Label Train Final:", np.shape(label_train_final))


model_simple_home_1 = models.Sequential()
model_simple_home_1.add(layers.Dense(50, activation='relu', input_shape=(115,)))
model_simple_home_1.add(layers.Dense(25, activation='relu'))
model_simple_home_1.add(layers.Dense(1, activation='sigmoid'))

model_simple_home_1.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_val = model_simple_home_1.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train: (368506, 115)
# Validation: (92127, 115)
# Label Validation: (92127,)
# Label Train Final: (368506,)
# Train on 368506 samples, validate on 92127 samples
# Epoch 1/50
# 368506/368506 [==============================] - 3s 7us/step - loss: 0.1628 - acc: 0.9618 - val_loss: 0.0309 - val_acc: 0.9945
# Epoch 2/50
# 368506/368506 [==============================] - 3s 7us/step - loss: 0.0237 - acc: 0.9955 - val_loss: 0.0210 - val_acc: 0.9955
# Epoch 3/50
# 368506/368506 [==============================] - 2s 7us/step - loss: 0.0188 - acc: 0.9957 - val_loss: 0.0186 - val_acc: 0.9959
# Epoch 4/50
# 368506/368506 [==============================] - 3s 7us/step - loss: 0.0171 - acc: 0.9962 - val_loss: 0.0173 - val_acc: 0.9961
# Epoch 5/50
# 368506/368506 [==============================] - 2s 7us/step - loss: 0.0160 - acc: 0.9963 - val_loss: 0.0163 - val_acc: 0.9963
# Epoch 6/50
# ...

# %%
pred_train = model_simple_home_1.predict(train_final).reshape(-1)
pred_test = model_simple_home_1.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.0010554139301408823
# MSE_val: 0.0012584062187446464

# %% [markdown]
# #### Iteration 2 - Regularization techniques - Dropout Layers

# %%
model_simple_home_2 = models.Sequential()
model_simple_home_2.add(layers.Dropout(0.3, input_shape=(115,)))
model_simple_home_2.add(layers.Dense(50, activation='relu'))
model_simple_home_2.add(layers.Dropout(0.3))
model_simple_home_2.add(layers.Dense(25, activation='relu'))
model_simple_home_2.add(layers.Dropout(0.3))
model_simple_home_2.add(layers.Dense(1, activation='sigmoid'))

model_simple_home_2.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_val = model_simple_home_2.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 368506 samples, validate on 92127 samples
# Epoch 1/50
# 368506/368506 [==============================] - 4s 10us/step - loss: 0.2599 - acc: 0.9068 - val_loss: 0.0346 - val_acc: 0.9938
# Epoch 2/50
# 368506/368506 [==============================] - 3s 9us/step - loss: 0.0703 - acc: 0.9837 - val_loss: 0.0241 - val_acc: 0.9958
# Epoch 3/50
# 368506/368506 [==============================] - 3s 9us/step - loss: 0.0515 - acc: 0.9892 - val_loss: 0.0229 - val_acc: 0.9959
# Epoch 4/50
# 368506/368506 [==============================] - 3s 9us/step - loss: 0.0442 - acc: 0.9909 - val_loss: 0.0221 - val_acc: 0.9959
# Epoch 5/50
# 368506/368506 [==============================] - 3s 9us/step - loss: 0.0403 - acc: 0.9921 - val_loss: 0.0215 - val_acc: 0.9959
# Epoch 6/50
# 368506/368506 [==============================] - 3s 9us/step - loss: 0.0373 - acc: 0.9927 - val_loss: 0.0207 - val_acc: 0.9959
# Epoch 7/50
# ...

# %%
pred_train = model_simple_home_2.predict(train_final).reshape(-1)
pred_test = model_simple_home_2.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.0014478044935971597
# MSE_val: 0.0016453144972166597

# %% [markdown]
# ### Model Performance and Analysis - SimpleHome 1002 WHT Security Camera

# %% [markdown]
# | Device Name | Iteration 1 Accuracy | Iteration 1 Loss | Iteration 2 Accuracy | Iteration 2 Loss |
# |------|------|------|------|------|
# | SimpleHome 1002 Security Camera | 99.87%  | 0.0052  | 99.73% | 0.0134 |

# %% [markdown]
# ### Provision PT 838 Security Camera

# %%
x = provision_838_1.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
provision_838_1_scaled= pd.DataFrame(x_scaled)

# %%
X = provision_838_1_scaled
y = provision_838_2["Benign/Attack"].as_matrix().T

# %%
X_resample, y_resample = SMOTE().fit_sample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resample, y_resample, test_size=0.2, random_state=0)

# %%
train_final = X_train[:371306]
label_train_final = y_train[:371306]

val = X_test[92827:]
label_val = y_test[92827:]

print("Train:", np.shape(train_final))
print("Validation:", np.shape(val))
print("Label Validation:", np.shape(label_val))
print("Label Train Final:", np.shape(label_train_final))
# Out:
# Train: (371306, 115)
# Validation: (92827, 115)
# Label Validation: (92827,)
# Label Train Final: (371306,)

# %% [markdown]
# #### Iteration 1 - Scaled Data (MinMax scaling implemented)

# %%
model_provision_838_1 = models.Sequential()
model_provision_838_1.add(layers.Dense(50, activation='relu', input_shape=(115,)))
model_provision_838_1.add(layers.Dense(25, activation='relu'))
model_provision_838_1.add(layers.Dense(1, activation='sigmoid')) # sigmoidal activation function added for final layer

# %%
model_provision_838_1.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model_val = model_provision_838_1.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 371306 samples, validate on 92827 samples
# Epoch 1/50
# 371306/371306 [==============================] - 3s 7us/step - loss: 0.1695 - acc: 0.9719 - val_loss: 0.0254 - val_acc: 0.9965
# Epoch 2/50
# 371306/371306 [==============================] - 3s 7us/step - loss: 0.0192 - acc: 0.9967 - val_loss: 0.0152 - val_acc: 0.9971
# Epoch 3/50
# 371306/371306 [==============================] - 3s 7us/step - loss: 0.0144 - acc: 0.9972 - val_loss: 0.0129 - val_acc: 0.9975
# Epoch 4/50
# 371306/371306 [==============================] - 3s 7us/step - loss: 0.0128 - acc: 0.9974 - val_loss: 0.0118 - val_acc: 0.9976
# Epoch 5/50
# 371306/371306 [==============================] - 3s 7us/step - loss: 0.0118 - acc: 0.9976 - val_loss: 0.0109 - val_acc: 0.9977
# Epoch 6/50
# 371306/371306 [==============================] - 3s 7us/step - loss: 0.0110 - acc: 0.9977 - val_loss: 0.0103 - val_acc: 0.9978
# Epoch 7/50
# ...

# %%
pred_train = model_provision_838_1.predict(train_final).reshape(-1)
pred_test = model_provision_838_1.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.0008321905298438414
# MSE_val: 0.0008492070935916177

# %% [markdown]
# #### Iteration 2 - Regularization techniques - Dropout Layers

# %%
model_provision_838_2 = models.Sequential()
model_provision_838_2.add(layers.Dropout(0.3, input_shape=(115,)))
model_provision_838_2.add(layers.Dense(50, activation='relu'))
model_provision_838_2.add(layers.Dropout(0.3))
model_provision_838_2.add(layers.Dense(25, activation='relu'))
model_provision_838_2.add(layers.Dropout(0.3))
model_provision_838_2.add(layers.Dense(1, activation='sigmoid'))

model_provision_838_2.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_val = model_provision_838_2.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 371306 samples, validate on 92827 samples
# Epoch 1/50
# 371306/371306 [==============================] - 4s 10us/step - loss: 0.2111 - acc: 0.9371 - val_loss: 0.0242 - val_acc: 0.9966
# Epoch 2/50
# 371306/371306 [==============================] - 3s 9us/step - loss: 0.0547 - acc: 0.9891 - val_loss: 0.0158 - val_acc: 0.9976
# Epoch 3/50
# 371306/371306 [==============================] - 3s 9us/step - loss: 0.0396 - acc: 0.9925 - val_loss: 0.0148 - val_acc: 0.9979
# Epoch 4/50
# 371306/371306 [==============================] - 3s 9us/step - loss: 0.0331 - acc: 0.9941 - val_loss: 0.0147 - val_acc: 0.9980
# Epoch 5/50
# 371306/371306 [==============================] - 4s 10us/step - loss: 0.0299 - acc: 0.9948 - val_loss: 0.0145 - val_acc: 0.9979
# Epoch 6/50
# 371306/371306 [==============================] - 3s 9us/step - loss: 0.0278 - acc: 0.9953 - val_loss: 0.0143 - val_acc: 0.9980
# Epoch 7/50
# ...

# %%
pred_train = model_provision_838_2.predict(train_final).reshape(-1)
pred_test = model_provision_838_2.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.0009627782436344766
# MSE_val: 0.0009626683247899415

# %% [markdown]
# ### Model Performance and Analysis - Provision PT 838 Security Camera

# %% [markdown]
# | Device Name | Iteration 1 Accuracy | Iteration 1 Loss | Iteration 2 Accuracy | Iteration 2 Loss |
# |------|------|------|------|------|
# | Provision 838 Security Camera | 99.91% | 0.0051  | 99.79% | 0.0152 |

# %% [markdown]
# ### SimpleHome 1003 Security Camera

# %%
x = simple_home_1003_1.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
simple_home_1003_1_scaled = pd.DataFrame(x_scaled)

# %%
X = simple_home_1003_1_scaled
y = simple_home_1003_2["Benign/Attack"].as_matrix().T

# %%
X_resample, y_resample = SMOTE().fit_sample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resample, y_resample, test_size=0.2, random_state=0)

# %%
train_final = X_train[:373839]
label_train_final = y_train[:373839]

val = X_test[93460:]
label_val = y_test[93460:]

print("Train:", np.shape(train_final))
print("Validation:", np.shape(val))
print("Label Validation:", np.shape(label_val))
print("Label Train Final:", np.shape(label_train_final))
# Out:
# Train: (373839, 115)
# Validation: (93460, 115)
# Label Validation: (93460,)
# Label Train Final: (373839,)

# %% [markdown]
# #### Iteration 1 - Scaled Data (MinMax scaling implemented)

# %%
model_simple_home_1003_1 = models.Sequential()
model_simple_home_1003_1.add(layers.Dense(50, activation='relu', input_shape=(115,)))
model_simple_home_1003_1.add(layers.Dense(25, activation='relu'))
model_simple_home_1003_1.add(layers.Dense(1, activation='sigmoid')) # sigmoidal activation function added for final layer

# %%
model_simple_home_1003_1.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model_val = model_simple_home_1003_1.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 373839 samples, validate on 93460 samples
# Epoch 1/50
# 373839/373839 [==============================] - 3s 8us/step - loss: 0.1270 - acc: 0.9902 - val_loss: 0.0296 - val_acc: 0.9947
# Epoch 2/50
# 373839/373839 [==============================] - 4s 10us/step - loss: 0.0243 - acc: 0.9950 - val_loss: 0.0212 - val_acc: 0.9953
# Epoch 3/50
# 373839/373839 [==============================] - 3s 8us/step - loss: 0.0196 - acc: 0.9953 - val_loss: 0.0183 - val_acc: 0.9955
# Epoch 4/50
# 373839/373839 [==============================] - 3s 7us/step - loss: 0.0173 - acc: 0.9956 - val_loss: 0.0165 - val_acc: 0.9959
# Epoch 5/50
# 373839/373839 [==============================] - 3s 7us/step - loss: 0.0158 - acc: 0.9959 - val_loss: 0.0152 - val_acc: 0.9960
# Epoch 6/50
# 373839/373839 [==============================] - 3s 7us/step - loss: 0.0146 - acc: 0.9960 - val_loss: 0.0141 - val_acc: 0.9963
# Epoch 7/50
# ...

# %%
pred_train = model_simple_home_1003_1.predict(train_final).reshape(-1)
pred_test = model_simple_home_1003_1.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.000865433019506349
# MSE_val: 0.0009940594639769615

# %% [markdown]
# #### Iteration 2 - Regularization techniques - Dropout Layers

# %%
model_simple_home_1003_2 = models.Sequential()
model_simple_home_1003_2.add(layers.Dropout(0.3, input_shape=(115,)))
model_simple_home_1003_2.add(layers.Dense(50, activation='relu'))
model_simple_home_1003_2.add(layers.Dropout(0.3))
model_simple_home_1003_2.add(layers.Dense(25, activation='relu'))
model_simple_home_1003_2.add(layers.Dropout(0.3))
model_simple_home_1003_2.add(layers.Dense(1, activation='sigmoid'))

model_simple_home_1003_2.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_val = model_simple_home_1003_2.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 373839 samples, validate on 93460 samples
# Epoch 1/50
# 373839/373839 [==============================] - 4s 11us/step - loss: 0.2145 - acc: 0.9329 - val_loss: 0.0298 - val_acc: 0.9949
# Epoch 2/50
# 373839/373839 [==============================] - 3s 9us/step - loss: 0.0628 - acc: 0.9877 - val_loss: 0.0253 - val_acc: 0.9954
# Epoch 3/50
# 373839/373839 [==============================] - 3s 9us/step - loss: 0.0494 - acc: 0.9905 - val_loss: 0.0234 - val_acc: 0.9955
# Epoch 4/50
# 373839/373839 [==============================] - 3s 9us/step - loss: 0.0434 - acc: 0.9921 - val_loss: 0.0219 - val_acc: 0.9956
# Epoch 5/50
# 373839/373839 [==============================] - 3s 9us/step - loss: 0.0394 - acc: 0.9928 - val_loss: 0.0207 - val_acc: 0.9957
# Epoch 6/50
# 373839/373839 [==============================] - 3s 9us/step - loss: 0.0366 - acc: 0.9933 - val_loss: 0.0197 - val_acc: 0.9958
# Epoch 7/50
# ...

# %%
pred_train = model_simple_home_1003_2.predict(train_final).reshape(-1)
pred_test = model_simple_home_1003_2.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.0010221759981055014
# MSE_val: 0.0011241699500883205

# %% [markdown]
# ### Model Performance and Analysis - SimpleHome 1003 Security Camera

# %% [markdown]
# | Device Name | Iteration 1 Accuracy | Iteration 1 Loss | Iteration 2 Accuracy | Iteration 2 Loss |
# |------|------|------|------|------|
# | Simple Home 1003 Security Camera | 99.90% | 0.0059  | 99.78% | 0.0112 |

# %% [markdown]
# ### Danmini Doorbell

# %%
x = danmini_doorbell_features_1.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
danmini_doorbell_featuers_1_scaled = pd.DataFrame(x_scaled)

# %%
X = danmini_doorbell_featuers_1_scaled
y = danmini_doorbell_target_2["Benign/Attack"].as_matrix().T

# %%
X_resample, y_resample = SMOTE().fit_sample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resample, y_resample, test_size=0.2, random_state=0)

# %%
train_final = X_train[:421224]
label_train_final = y_train[:421224]

val = X_test[105306:]
label_val = y_test[105306:]

print("Train:", np.shape(train_final))
print("Validation:", np.shape(val))
print("Label Validation:", np.shape(label_val))
print("Label Train Final:", np.shape(label_train_final))
# Out:
# Train: (421224, 115)
# Validation: (105306, 115)
# Label Validation: (105306,)
# Label Train Final: (421224,)

# %% [markdown]
# #### Iteration 1 - Scaled Data (MinMax scaling implemented)

# %%
danmini_doorbell_model_1 = models.Sequential()
danmini_doorbell_model_1.add(layers.Dense(50, activation='relu', input_shape=(115,)))
danmini_doorbell_model_1.add(layers.Dense(25, activation='relu'))
danmini_doorbell_model_1.add(layers.Dense(1, activation='sigmoid'))

# %%
danmini_doorbell_model_1.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model_val = danmini_doorbell_model_1.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 421224 samples, validate on 105306 samples
# Epoch 1/50
# 421224/421224 [==============================] - 7s 16us/step - loss: 0.0997 - acc: 0.9833 - val_loss: 0.0265 - val_acc: 0.9948
# Epoch 2/50
# 421224/421224 [==============================] - 4s 9us/step - loss: 0.0203 - acc: 0.9962 - val_loss: 0.0193 - val_acc: 0.9963
# Epoch 3/50
# 421224/421224 [==============================] - 4s 9us/step - loss: 0.0163 - acc: 0.9968 - val_loss: 0.0169 - val_acc: 0.9965
# Epoch 4/50
# 421224/421224 [==============================] - 3s 8us/step - loss: 0.0147 - acc: 0.9970 - val_loss: 0.0156 - val_acc: 0.9967
# Epoch 5/50
# 421224/421224 [==============================] - 4s 9us/step - loss: 0.0136 - acc: 0.9972 - val_loss: 0.0146 - val_acc: 0.9968
# Epoch 6/50
# 421224/421224 [==============================] - 4s 9us/step - loss: 0.0127 - acc: 0.9973 - val_loss: 0.0136 - val_acc: 0.9969
# Epoch 7/50
# ...

# %%
pred_train = danmini_doorbell_model_1.predict(train_final).reshape(-1)
pred_test = danmini_doorbell_model_1.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.0008254660802908393
# MSE_val: 0.0008877909863312185

# %% [markdown]
# #### Iteration 2 - Regularization techniques - Dropout Layers

# %%
danmini_doorbell_model_2 = models.Sequential()
danmini_doorbell_model_2.add(layers.Dropout(0.3, input_shape=(115,)))
danmini_doorbell_model_2.add(layers.Dense(50, activation='relu'))
danmini_doorbell_model_2.add(layers.Dropout(0.3))
danmini_doorbell_model_2.add(layers.Dense(25, activation='relu'))
danmini_doorbell_model_2.add(layers.Dropout(0.3))
danmini_doorbell_model_2.add(layers.Dense(1, activation='sigmoid'))

danmini_doorbell_model_2.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_val = danmini_doorbell_model_2.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 421224 samples, validate on 105306 samples
# Epoch 1/50
# 421224/421224 [==============================] - 7s 16us/step - loss: 0.1897 - acc: 0.9477 - val_loss: 0.0264 - val_acc: 0.9956
# Epoch 2/50
# 421224/421224 [==============================] - 5s 11us/step - loss: 0.0533 - acc: 0.9900 - val_loss: 0.0225 - val_acc: 0.9966
# Epoch 3/50
# 421224/421224 [==============================] - 5s 11us/step - loss: 0.0414 - acc: 0.9929 - val_loss: 0.0220 - val_acc: 0.9970
# Epoch 4/50
# 421224/421224 [==============================] - 4s 10us/step - loss: 0.0367 - acc: 0.9942 - val_loss: 0.0216 - val_acc: 0.9971
# Epoch 5/50
# 421224/421224 [==============================] - 5s 11us/step - loss: 0.0337 - acc: 0.9947 - val_loss: 0.0208 - val_acc: 0.9972
# Epoch 6/50
# 421224/421224 [==============================] - 4s 11us/step - loss: 0.0311 - acc: 0.9952 - val_loss: 0.0200 - val_acc: 0.9972
# Epoch 7/50
# ...

# %%
pred_train = danmini_doorbell_model_2.predict(train_final).reshape(-1)
pred_test = danmini_doorbell_model_2.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.0013519223174550845
# MSE_val: 0.0014279339201326048

# %% [markdown]
# ### Model Performance and Analysis - Danmini Doorbell

# %% [markdown]
# | Device Name | Iteration 1 Accuracy | Iteration 1 Loss | Iteration 2 Accuracy | Iteration 2 Loss |
# |------|------|------|------|------|
# | Danmini Doorbell | 99.89% | 0.0037  | 99.77%  | 0.0149 |

# %% [markdown]
# ### Ennio Doorbell

# %%
x = ennio_doorbell_1.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
ennio_doorbell_1_scaled = pd.DataFrame(x_scaled)

# %%
X = ennio_doorbell_1_scaled
y = ennio_doorbell_target_2["Benign/Attack"].as_matrix().T

# %%
X_resample, y_resample = SMOTE().fit_sample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resample, y_resample, test_size=0.2, random_state=0)

# %%
train_final_ennio = X_train[:253120]
label_train_final_ennio = y_train[:253120]

val_ennio = X_test[63280:]
label_val_ennio = y_test[63280:]

print("Train:", np.shape(train_final_ennio))
print("Validation:", np.shape(val_ennio))
print("Label Validation:", np.shape(label_val_ennio))
print("Label Train Final:", np.shape(label_train_final_ennio))
# Out:
# Train: (253120, 115)
# Validation: (63280, 115)
# Label Validation: (63280,)
# Label Train Final: (253120,)

# %% [markdown]
# #### Iteration 1 - Scaled Data (MinMax scaling implemented)

# %%
ennio_doorbell_model_1 = models.Sequential()
ennio_doorbell_model_1.add(layers.Dense(50, activation='relu', input_shape=(115,)))
ennio_doorbell_model_1.add(layers.Dense(25, activation='relu'))
ennio_doorbell_model_1.add(layers.Dense(1, activation='sigmoid')) # sigmoidal activation function added for final layer

# %%
ennio_doorbell_model_1.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model_val = ennio_doorbell_model_1.fit(train_final_ennio,
                    label_train_final_ennio,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 253120 samples, validate on 19784 samples
# Epoch 1/50
# 253120/253120 [==============================] - 4s 17us/step - loss: 0.2321 - acc: 0.9368 - val_loss: 0.0647 - val_acc: 0.9972
# Epoch 2/50
# 253120/253120 [==============================] - 2s 10us/step - loss: 0.0326 - acc: 0.9942 - val_loss: 0.0354 - val_acc: 0.9974
# Epoch 3/50
# 253120/253120 [==============================] - 2s 9us/step - loss: 0.0255 - acc: 0.9950 - val_loss: 0.0290 - val_acc: 0.9975
# Epoch 4/50
# 253120/253120 [==============================] - 2s 9us/step - loss: 0.0232 - acc: 0.9955 - val_loss: 0.0266 - val_acc: 0.9975
# Epoch 5/50
# 253120/253120 [==============================] - 2s 8us/step - loss: 0.0218 - acc: 0.9957 - val_loss: 0.0253 - val_acc: 0.9974
# Epoch 6/50
# 253120/253120 [==============================] - 2s 8us/step - loss: 0.0208 - acc: 0.9958 - val_loss: 0.0252 - val_acc: 0.9972
# Epoch 7/50
# ...

# %%
pred_train = ennio_doorbell_model_1.predict(train_final).reshape(-1)
pred_test = ennio_doorbell_model_1.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.008036079312877928
# MSE_val: 0.00763362372593083

# %% [markdown]
# #### Iteration 2 - Regularization techniques - Dropout Layers

# %%
ennio_doorbell_model_2 = models.Sequential()
ennio_doorbell_model_2.add(layers.Dropout(0.3, input_shape=(115,)))
ennio_doorbell_model_2.add(layers.Dense(50, activation='relu'))
ennio_doorbell_model_2.add(layers.Dropout(0.3))
ennio_doorbell_model_2.add(layers.Dense(25, activation='relu'))
ennio_doorbell_model_2.add(layers.Dropout(0.3))
ennio_doorbell_model_2.add(layers.Dense(1, activation='sigmoid'))

ennio_doorbell_model_2.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_val = ennio_doorbell_model_2.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 421224 samples, validate on 19784 samples
# Epoch 1/50
# 421224/421224 [==============================] - 6s 15us/step - loss: 0.2278 - acc: 0.9319 - val_loss: 0.0250 - val_acc: 0.9963
# Epoch 2/50
# 421224/421224 [==============================] - 4s 11us/step - loss: 0.0562 - acc: 0.9892 - val_loss: 0.0179 - val_acc: 0.9975
# Epoch 3/50
# 421224/421224 [==============================] - 5s 12us/step - loss: 0.0411 - acc: 0.9931 - val_loss: 0.0177 - val_acc: 0.9974
# Epoch 4/50
# 421224/421224 [==============================] - 4s 10us/step - loss: 0.0347 - acc: 0.9946 - val_loss: 0.0178 - val_acc: 0.9975
# Epoch 5/50
# 421224/421224 [==============================] - 5s 12us/step - loss: 0.0312 - acc: 0.9953 - val_loss: 0.0178 - val_acc: 0.9975
# Epoch 6/50
# 421224/421224 [==============================] - 5s 11us/step - loss: 0.0292 - acc: 0.9955 - val_loss: 0.0177 - val_acc: 0.9976
# Epoch 7/50
# ...

# %%
pred_train = ennio_doorbell_model_2.predict(train_final).reshape(-1)
pred_test = ennio_doorbell_model_2.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.0007825752323348537
# MSE_val: 0.0009869338632617173

# %% [markdown]
# #### Ennio Doorbell - Model Performance and Analysis

# %% [markdown]
# | Device Name | Iteration 1 Accuracy | Iteration 1 Loss | Iteration 2 Accuracy | Iteration 2 Loss |
# |------|------|------|------|------|
# | Ennio Doorbell  | 99.77% | 0.0128  | 99.81% | 0.0142 |

# %% [markdown]
# ### Philips Baby Monitor

# %%
x = philips_baby_monitor_1.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
philips_baby_monitor_1_scaled = pd.DataFrame(x_scaled)

# %%
X = philips_baby_monitor_1_scaled
y = philips_baby_monitor_target_2["Benign/Attack"].as_matrix().T

# %%
X_resample, y_resample = SMOTE().fit_sample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resample, y_resample, test_size=0.2, random_state=0)

# %%
train_final = X_train[:421224]
label_train_final = y_train[:421224]

val = X_test[105306:]
label_val = y_test[105306:]

print("Train:", np.shape(train_final))
print("Validation:", np.shape(val))
print("Label Validation:", np.shape(label_val))
print("Label Train Final:", np.shape(label_train_final))
# Out:
# Train: (421224, 115)
# Validation: (19784, 115)
# Label Validation: (19784,)
# Label Train Final: (421224,)

# %% [markdown]
# #### Iteration 1 - Scaled Data (MinMax scaling implemented)

# %%
philips_baby_monitor_model_1 = models.Sequential()
philips_baby_monitor_model_1.add(layers.Dense(50, activation='relu', input_shape=(115,)))
philips_baby_monitor_model_1.add(layers.Dense(25, activation='relu'))
philips_baby_monitor_model_1.add(layers.Dense(1, activation='sigmoid'))

# %%
philips_baby_monitor_model_1.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model_val = philips_baby_monitor_model_1.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 421224 samples, validate on 19784 samples
# Epoch 1/50
# 421224/421224 [==============================] - 6s 14us/step - loss: 0.0870 - acc: 0.9864 - val_loss: 0.0210 - val_acc: 0.9966
# Epoch 2/50
# 421224/421224 [==============================] - 4s 9us/step - loss: 0.0157 - acc: 0.9974 - val_loss: 0.0154 - val_acc: 0.9975
# Epoch 3/50
# 421224/421224 [==============================] - 4s 10us/step - loss: 0.0129 - acc: 0.9978 - val_loss: 0.0140 - val_acc: 0.9975
# Epoch 4/50
# 421224/421224 [==============================] - 4s 10us/step - loss: 0.0118 - acc: 0.9978 - val_loss: 0.0131 - val_acc: 0.9975
# Epoch 5/50
# 421224/421224 [==============================] - 5s 12us/step - loss: 0.0111 - acc: 0.9978 - val_loss: 0.0124 - val_acc: 0.9975
# Epoch 6/50
# 421224/421224 [==============================] - 4s 9us/step - loss: 0.0105 - acc: 0.9979 - val_loss: 0.0117 - val_acc: 0.9975
# Epoch 7/50
# ...

# %%
pred_train = philips_baby_monitor_model_1.predict(train_final).reshape(-1)
pred_test = philips_baby_monitor_model_1.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.0006185023699158443
# MSE_val: 0.0007218858906078874

# %% [markdown]
# #### Iteration 2 - Regularization techniques - Dropout Layers

# %%
philips_baby_monitor_model_2 = models.Sequential()
philips_baby_monitor_model_2.add(layers.Dropout(0.3, input_shape=(115,)))
philips_baby_monitor_model_2.add(layers.Dense(50, activation='relu'))
philips_baby_monitor_model_2.add(layers.Dropout(0.3))
philips_baby_monitor_model_2.add(layers.Dense(25, activation='relu'))
philips_baby_monitor_model_2.add(layers.Dropout(0.3))
philips_baby_monitor_model_2.add(layers.Dense(1, activation='sigmoid'))

philips_baby_monitor_model_2.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_val = philips_baby_monitor_model_2.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 421224 samples, validate on 19784 samples
# Epoch 1/50
# 421224/421224 [==============================] - 6s 14us/step - loss: 0.2062 - acc: 0.9412 - val_loss: 0.0242 - val_acc: 0.9963
# Epoch 2/50
# 421224/421224 [==============================] - 4s 10us/step - loss: 0.0529 - acc: 0.9896 - val_loss: 0.0177 - val_acc: 0.9975
# Epoch 3/50
# 421224/421224 [==============================] - 5s 11us/step - loss: 0.0371 - acc: 0.9934 - val_loss: 0.0175 - val_acc: 0.9975
# Epoch 4/50
# 421224/421224 [==============================] - 4s 10us/step - loss: 0.0317 - acc: 0.9946 - val_loss: 0.0176 - val_acc: 0.9975
# Epoch 5/50
# 421224/421224 [==============================] - 5s 11us/step - loss: 0.0288 - acc: 0.9953 - val_loss: 0.0176 - val_acc: 0.9975
# Epoch 6/50
# 421224/421224 [==============================] - 6s 15us/step - loss: 0.0268 - acc: 0.9956 - val_loss: 0.0172 - val_acc: 0.9975
# Epoch 7/50
# ...

# %%
pred_train = philips_baby_monitor_model_2.predict(train_final).reshape(-1)
pred_test = philips_baby_monitor_model_2.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.0007440166833706242
# MSE_val: 0.0009201465306003797

# %% [markdown]
# ### Model Performance and Analysis - Philips Baby Monitor

# %% [markdown]
# | Device Name | Iteration 1 Accuracy | Iteration 1 Loss | Iteration 2 Accuracy | Iteration 2 Loss |
# |------|------|------|------|------|
# | Philips Baby Monitor | 99.93% | 0.0038  | 99.79%  | 0.0144 |

# %% [markdown]
# ### Ecobee Thermostat

# %%
x = ecobee_thermostat_1.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
ecobee_thermostat_1_scaled = pd.DataFrame(x_scaled)

# %%
X = ecobee_thermostat_1_scaled
y = ecobee_thermostat_2["Benign/Attack"].as_matrix().T

# %%
X_resample, y_resample = SMOTE().fit_sample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resample, y_resample, test_size=0.2, random_state=0)

# %%
train_final_ecobee = X_train[:421224]
label_train_final_ecobee = y_train[:421224]

val_ecobee = X_test[105306:]
label_val_ecobee = y_test[105306:]

print("Train:", np.shape(train_final_ecobee))
print("Validation:", np.shape(val_ecobee))
print("Label Validation:", np.shape(label_val_ecobee))
print("Label Train Final:", np.shape(label_train_final_ecobee))
# Out:
# Train: (421224, 115)
# Validation: (81537, 115)
# Label Validation: (81537,)
# Label Train Final: (421224,)

# %% [markdown]
# #### Iteration 1 - Scaled Data (MinMax scaling implemented)

# %%
ecobee_thermostat_model_1 = models.Sequential()
ecobee_thermostat_model_1.add(layers.Dense(50, activation='relu', input_shape=(115,)))
ecobee_thermostat_model_1.add(layers.Dense(25, activation='relu'))
ecobee_thermostat_model_1.add(layers.Dense(1, activation='sigmoid'))

# %%
ecobee_thermostat_model_1.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model_val = ecobee_thermostat_model_1.fit(train_final_ecobee,
                    label_train_final_ecobee,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 421224 samples, validate on 19784 samples
# Epoch 1/50
# 421224/421224 [==============================] - 6s 14us/step - loss: 0.1014 - acc: 0.9803 - val_loss: 0.0559 - val_acc: 0.9975
# Epoch 2/50
# 421224/421224 [==============================] - 3s 8us/step - loss: 0.0160 - acc: 0.9971 - val_loss: 0.0388 - val_acc: 0.9975
# Epoch 3/50
# 421224/421224 [==============================] - 4s 9us/step - loss: 0.0125 - acc: 0.9975 - val_loss: 0.0331 - val_acc: 0.9975
# Epoch 4/50
# 421224/421224 [==============================] - 3s 8us/step - loss: 0.0109 - acc: 0.9977 - val_loss: 0.0319 - val_acc: 0.9976
# Epoch 5/50
# 421224/421224 [==============================] - 4s 9us/step - loss: 0.0099 - acc: 0.9978 - val_loss: 0.0322 - val_acc: 0.9976
# Epoch 6/50
# 421224/421224 [==============================] - 3s 8us/step - loss: 0.0090 - acc: 0.9979 - val_loss: 0.0322 - val_acc: 0.9977
# Epoch 7/50
# ...

# %%
pred_train = ecobee_thermostat_model_1.predict(train_final).reshape(-1)
pred_test = ecobee_thermostat_model_1.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.009177602335904384
# MSE_val: 0.009171098779506236

# %% [markdown]
# #### Iteration 2 - Regularization techniques - Dropout Layers

# %%
ecobee_thermostat_model_2 = models.Sequential()
ecobee_thermostat_model_2.add(layers.Dropout(0.3, input_shape=(115,)))
ecobee_thermostat_model_2.add(layers.Dense(50, activation='relu'))
ecobee_thermostat_model_2.add(layers.Dropout(0.3))
ecobee_thermostat_model_2.add(layers.Dense(25, activation='relu'))
ecobee_thermostat_model_2.add(layers.Dropout(0.3))
ecobee_thermostat_model_2.add(layers.Dense(1, activation='sigmoid'))

ecobee_thermostat_model_2.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_val = ecobee_thermostat_model_2.fit(train_final,
                    label_train_final,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val, label_val))
# Out:
# Train on 421224 samples, validate on 19784 samples
# Epoch 1/50
# 421224/421224 [==============================] - 6s 15us/step - loss: 0.2029 - acc: 0.9410 - val_loss: 0.0234 - val_acc: 0.9961
# Epoch 2/50
# 421224/421224 [==============================] - 7s 16us/step - loss: 0.0527 - acc: 0.9901 - val_loss: 0.0170 - val_acc: 0.9975
# Epoch 3/50
# 421224/421224 [==============================] - 5s 13us/step - loss: 0.0380 - acc: 0.9937 - val_loss: 0.0167 - val_acc: 0.9974
# Epoch 4/50
# 421224/421224 [==============================] - 5s 13us/step - loss: 0.0319 - acc: 0.9949 - val_loss: 0.0167 - val_acc: 0.9975
# Epoch 5/50
# 421224/421224 [==============================] - 5s 11us/step - loss: 0.0289 - acc: 0.9955 - val_loss: 0.0165 - val_acc: 0.9975
# Epoch 6/50
# 421224/421224 [==============================] - 5s 12us/step - loss: 0.0269 - acc: 0.9959 - val_loss: 0.0163 - val_acc: 0.9975
# Epoch 7/50
# ...

# %%
pred_train = ecobee_thermostat_model_2.predict(train_final).reshape(-1)
pred_test = ecobee_thermostat_model_2.predict(val).reshape(-1)

MSE_train = np.mean((pred_train-label_train_final)**2)
MSE_val = np.mean((pred_test-label_val)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.0008426515387790677
# MSE_val: 0.0010668636792499821

# %% [markdown]
# ### Model Performance and Analysis - Ecobee Thermostat

# %% [markdown]
# | Device Name | Iteration 1 Accuracy | Iteration 1 Loss | Iteration 2 Accuracy | Iteration 2 Loss |
# |------|------|------|------|------|
# | Ecobee Thermostat | 99.92% | 0.0044  | 99.81% | 0.0139 |

# %% [markdown]
# ### First Round Analysis

# %% [markdown]
# | Rank | Device Name | Iteration 1 Accuracy | Iteration 1 Loss | Iteration 2 Accuracy | Iteration 2 Loss |
# |------|------|------|------|------|------|
# | 1 | Ecobee Thermostat | 99.92% | 0.0044  | 99.81% | 0.0139 |
# | 2 | Philips Baby Monitor | 99.91% | 0.0044  | 99.80%  | 0.0141 |
# | 3 | Provision 838 Security Camera | 99.91% | 0.0051  | 99.79% | 0.0152 |
# | 4 | Simple Home 1003 Security Camera | 99.90% | 0.0059  | 99.78% | 0.0112 |
# | 5 | Provision 738E Security Camera  | 99.88% | 0.0072  | 99.77%  | 0.0170 |
# | 6 | Danmini Doorbell | 99.88% | 0.0038  | 99.77%  | 0.0149 |
# | 7 | SimpleHome 1002 Security Camera | 99.87%  | 0.0052  | 99.73% | 0.0134 |
# | 8 | Ennio Doorbell  | 99.77% | 0.0128  | 99.81% | 0.0142 |

# %% [markdown]
# After 1 round of training on the individual device datasets, we see that the Ecobee Thermostat model performed the best and achieved 99.92% accuracy on its first iteration with a very low loss level, 0.0044. Surprisingly, we see the Philips Baby Monitor in second place with 99.91% accuracy. These results were surprising to me at first. I went into testing believing that the simpler devices with fewer functions and capabilities would produce more consistent network behavior and therefore be easier to classify on. Modern thermostats and baby monitors are complex devices (sometimes Wi-Fi connected) responsibile for continuous controlling of and measuring of temperature and humidity or, in the case of a baby monitor, two-way communication.
# <br>
# <br>
# I was surprised to see some of the above results when comparing initial models to dropout regularization models for the same device. For all but one device (Ennio Doorbell), the initial model slightly outperformed the dropout model resulting in lower loss values and higher classification accuracy.

# %% [markdown]
# ### Testing at a More General Level
# <br>
# Beyond testing these neural network models on the individual testing data from the original test sets, I was also curious to see which would perform best using a generalized data set from all 8 devices. To puruse this endeavor, I needed to grab a uniform partition of data from each dataset, concatenate it into a single dataframe, and then run each of the 16 models using this newly formed data to measure the overall performance.

# %%
# Provision 737 Security Camera
round_2_provision_737_1_scaled = provision_737_1_scaled[:100000]
round_2_provision_737_2 = provision_737_2[:100000]

# Ecobee Thermostat
round_2_ecobee_thermostat_1_scaled = ecobee_thermostat_1_scaled[:100000]
round_2_ecobee_thermostat_2 = ecobee_thermostat_2[:100000]

# Philips Baby Monitor
round_2_philips_baby_monitor_1_scaled = philips_baby_monitor_1_scaled[:100000]
round_2_philips_baby_monitor_2 = philips_baby_monitor_target_2[:100000]

# Provision 838 Security Camera
round_2_provision_838_1_scaled = provision_838_1_scaled[:100000]
round_2_provision_838_2 = provision_838_2[:100000]

# Simple Home 1003 Security Camera
round_2_simple_home_1003_1_scaled = simple_home_1003_1_scaled[:100000]
round_2_simple_home_1003_2 = simple_home_1003_2[:100000]

# Provision 738E Security Camera
round_2_provision_737_1_scaled = provision_737_1_scaled[:100000]
round_2_provision_737_2 = provision_737_2[:100000]

# Danmini Doorbell
round_2_danmini_doorbell_1_scaled = danmini_doorbell_1_scaled[:100000]
round_2_danmini_doorbell_2 = danmini_doorbell_2[:100000]

# SimpleHome 1002 Security Camera
round_2_simple_home_1002_1_scaled = simple_home_1002_1_scaled[:100000]
round_2_simple_home_1002_2 = simple_home_1002_2[:100000]

# Ennio Doorbell
round_2_ennio_doorbell_1_scaled = ennio_doorbell_1_scaled[:100000]
round_2_ennio_doorbell_target_2 = ennio_doorbell_target_2[:100000]

# %%
round_2_concat_features = pd.concat([round_2_provision_737_1_scaled, round_2_ecobee_thermostat_1_scaled, 
                                    round_2_philips_baby_monitor_1_scaled, round_2_provision_838_1_scaled, 
                                    round_2_simple_home_1003_1_scaled, round_2_provision_737_1_scaled, 
                                    round_2_danmini_doorbell_1_scaled, round_2_simple_home_1002_1_scaled, 
                                    round_2_ennio_doorbell_1_scaled])
round_2_concat_targets = pd.concat([round_2_provision_737_2, round_2_ecobee_thermostat_2, 
                                   round_2_philips_baby_monitor_2, round_2_provision_838_2, 
                                   round_2_simple_home_1003_2, round_2_provision_737_2, round_2_danmini_doorbell_2, 
                                   round_2_simple_home_1002_2, round_2_ennio_doorbell_target_2])

# %%
# During the concatenation process, an additional column of NaN values was added to the dataframe which 
# caused several errors. After removing that column, I could proceed with the model

# %%
round_2_concat_features_2 = round_2_concat_features.drop([round_2_concat_features.columns[115]], axis="columns")
round_2_concat_features_2.head()
# Out:
#         0         1         2         3             4             5    \
# 0  0.000000  0.000000  0.000000  0.000000  1.387779e-17  0.000000e+00
# 1  0.000000  0.641517  0.000000  0.000000  6.740256e-01  0.000000e+00
# 2  0.003107  0.641517  0.000000  0.002372  6.740256e-01  3.839763e-16
# 3  0.000000  0.000000  0.000000  0.000000  1.387779e-17  0.000000e+00
# 4  0.003229  0.007337  0.000088  0.002427  7.677659e-03  1.191605e-04
#
#         6             7         8         9      ...          105       106  \
# 0  0.000000  1.387779e-17  0.000000  0.000000    ...     0.000000  0.311243
# 1  0.000000  8.157294e-01  0.000000  0.000000    ...     0.033545  0.311243
# 2  0.001025  8.157294e-01  0.000000  0.000125    ...     0.025713  0.311243
# 3  0.000000  1.387779e-17  0.000000  0.000000    ...     0.000000  0.311243
# 4  0.001033  9.253706e-03  0.000208  0.000126    ...     0.000000  0.311243
#
#         107       108           109       110           111       112  \
# ...

# %% [markdown]
# ### Building a General Botnet Classifier

# %%
X = round_2_concat_features_2
y = round_2_concat_targets["Benign/Attack"].as_matrix().T

# %%
X_resample, y_resample = SMOTE().fit_sample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resample, y_resample, test_size=0.2, random_state=0)

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 785113
# 196279

# %%
train_final_general = X_train[:392556]
label_train_final_general = y_train[:392556]

val_general = X_test[98139:]
label_val_general = y_test[98139:]

print("Train:", np.shape(train_final))
print("Validation:", np.shape(val))
print("Label Validation:", np.shape(label_val))
print("Label Train Final:", np.shape(label_train_final))
# Out:
# Train: (421224, 115)
# Validation: (19784, 115)
# Label Validation: (19784,)
# Label Train Final: (421224,)

# %% [markdown]
# ### List of Created Models

# %%
# Provision PT 737E
model_provision
model_provision_2

# Provision PT 838
model_provision_838_1
model_provision_838_2

# SimpleHome 1002
model_simple_home_1
model_simple_home_2

# SimpleHome 1003
model_simple_home_1003_1
model_simple_home_1003_2

# Danmini Doorbell
danmini_doorbell_model_1
danmini_doorbell_model_2

# Ennio Doorbell
ennio_doorbell_1
ennio_doorbell_2

# Ecobee SmartThermostat
ecobee_thermostat_model_1
ecobee_thermostat_model_2

# Philips Baby Monitor
philips_baby_monitor_1
philips_baby_monitor_2

# %% [markdown]
# ### Provision PT 737E

# %%
pred_train_provision_737 = model_provision.predict(train_final_general).reshape(-1)
pred_test_provision_737 = model_provision.predict(val_general).reshape(-1)

MSE_train_provision_737 = np.mean((pred_train_provision_737-label_train_final_general)**2)
MSE_val_provision_737 = np.mean((pred_test_provision_737-label_val_general)**2)

print("MSE_train:", MSE_train_provision_737)
print("MSE_val:", MSE_val_provision_737)
# Out:
# MSE_train: 0.0036379452397376946
# MSE_val: 0.0036738563117005253

# %%
pred_train_provision_737_2 = model_provision_2.predict(train_final_general).reshape(-1)
pred_test_provision_737_2 = model_provision_2.predict(val_general).reshape(-1)

MSE_train_provision_737_2 = np.mean((pred_train_provision_737_2-label_train_final_general)**2)
MSE_val_provision_737_2 = np.mean((pred_test_provision_737_2-label_val_general)**2)

print("MSE_train:", MSE_train_provision_737_2)
print("MSE_val:", MSE_val_provision_737_2)
# Out:
# MSE_train: 0.003888246707349046
# MSE_val: 0.003854582154575655

# %% [markdown]
# ### Provision PT 838

# %%
pred_train_provision_838 = model_provision_838_1.predict(train_final_general).reshape(-1)
pred_test_provision_838 = model_provision_838_1.predict(val_general).reshape(-1)

MSE_train_provision_838 = np.mean((pred_train_provision_838-label_train_final_general)**2)
MSE_val_provision_838 = np.mean((pred_test_provision_838-label_val_general)**2)

print("MSE_train:", MSE_train_provision_838)
print("MSE_val:", MSE_val_provision_838)
# Out:
# MSE_train: 0.0038024962418350323
# MSE_val: 0.003887114632422493

# %%
pred_train_provision_838_2 = model_provision_838_2.predict(train_final_general).reshape(-1)
pred_test_provision_838_2 = model_provision_838_2.predict(val_general).reshape(-1)

MSE_train_provision_838_2 = np.mean((pred_train_provision_838_2-label_train_final_general)**2)
MSE_val_provision_838_2 = np.mean((pred_test_provision_838_2-label_val_general)**2)

print("MSE_train:", MSE_train)
print("MSE_val:", MSE_val)
# Out:
# MSE_train: 0.005088467107712645
# MSE_val: 0.00494103849670818

# %% [markdown]
# ### SimpleHome 1002

# %%
pred_train_simplehome_1002 = model_simple_home_1.predict(train_final_general).reshape(-1)
pred_test_simplehome_1002 = model_simple_home_1.predict(val_general).reshape(-1)

MSE_train_simplehome_1002 = np.mean((pred_train_simplehome_1002-label_train_final_general)**2)
MSE_val_simplehome_1002 = np.mean((pred_test_simplehome_1002-label_val_general)**2)

print("MSE_train:", MSE_train_simplehome_1002)
print("MSE_val:", MSE_val_simplehome_1002)
# Out:
# MSE_train: 0.012762210372411112
# MSE_val: 0.012280873235525989

# %%
pred_train_simplehome_1002_2 = model_simple_home_2.predict(train_final_general).reshape(-1)
pred_test_simplehome_1002_2 = model_simple_home_2.predict(val_general).reshape(-1)

MSE_train_simplehome_1002_2 = np.mean((pred_train_simplehome_1002_2-label_train_final_general)**2)
MSE_val_simplehome_1002_2 = np.mean((pred_test_simplehome_1002_2-label_val_general)**2)

print("MSE_train:", MSE_train_simplehome_1002_2)
print("MSE_val:", MSE_val_simplehome_1002_2)
# Out:
# MSE_train: 0.0023108612938640776
# MSE_val: 0.0021846602595447877

# %% [markdown]
# ### SimpleHome 1003

# %%
pred_train_simplehome_1003 = model_simple_home_1003_1.predict(train_final_general).reshape(-1)
pred_test_simplehome_1003 = model_simple_home_1003_1.predict(val_general).reshape(-1)

MSE_train_simplehome_1003 = np.mean((pred_train_simplehome_1003-label_train_final_general)**2)
MSE_val_simplehome_1003 = np.mean((pred_test_simplehome_1003-label_val_general)**2)

print("MSE_train:", MSE_train_simplehome_1003)
print("MSE_val:", MSE_val_simplehome_1003)
# Out:
# MSE_train: 0.019822736567638347
# MSE_val: 0.019046291597112987

# %%
pred_train_simplehome_1003_2 = model_simple_home_1003_2.predict(train_final_general).reshape(-1)
pred_test_simplehome_1003_2 = model_simple_home_1003_2.predict(val_general).reshape(-1)

MSE_train_simplehome_1003_2 = np.mean((pred_train_simplehome_1003_2-label_train_final_general)**2)
MSE_val_simplehome_1003_2 = np.mean((pred_test_simplehome_1003_2-label_val_general)**2)

print("MSE_train:", MSE_train_simplehome_1003_2)
print("MSE_val:", MSE_val_simplehome_1003_2)
# Out:
# MSE_train: 0.018136393915666627
# MSE_val: 0.01819769958560781

# %% [markdown]
# ### Danmini Doorbell

# %%
pred_train_danmini = danmini_doorbell_model_1.predict(train_final_general).reshape(-1)
pred_test_danmini = danmini_doorbell_model_1.predict(val_general).reshape(-1)

MSE_train_danmini = np.mean((pred_train_danmini-label_train_final_general)**2)
MSE_val_danmini = np.mean((pred_test_danmini-label_val_general)**2)

print("MSE_train:", MSE_train_danmini)
print("MSE_val:", MSE_val_danmini)
# Out:
# MSE_train: 0.01598737619098169
# MSE_val: 0.015350598722230087

# %%
pred_train_danmini_2 = danmini_doorbell_model_2.predict(train_final_general).reshape(-1)
pred_test_danmini_2 = danmini_doorbell_model_2.predict(val_general).reshape(-1)

MSE_train_danmini_2 = np.mean((pred_train_danmini_2-label_train_final_general)**2)
MSE_val_danmini_2 = np.mean((pred_test_danmini_2-label_val_general)**2)

print("MSE_train:", MSE_train_danmini_2)
print("MSE_val:", MSE_val_danmini_2)
# Out:
# MSE_train: 0.01607358025114879
# MSE_val: 0.015986871333328136

# %% [markdown]
# ### Ennio Doorbell

# %%
pred_train_ennio = ennio_doorbell_model_1.predict(train_final_general).reshape(-1)
pred_test_ennio = ennio_doorbell_model_1.predict(val_general).reshape(-1)

MSE_train_ennio = np.mean((pred_train_ennio-label_train_final_general)**2)
MSE_val_ennio = np.mean((pred_test_ennio-label_val_general)**2)

print("MSE_train:", MSE_train_ennio)
print("MSE_val:", MSE_val_ennio)
# Out:
# MSE_train: 0.01876647182288731
# MSE_val: 0.01898285498194691

# %%
pred_train_ennio_2 = ennio_doorbell_model_2.predict(train_final_general).reshape(-1)
pred_test_ennio_2 = ennio_doorbell_model_2.predict(val_general).reshape(-1)

MSE_train_ennio_2 = np.mean((pred_train_ennio_2-label_train_final_general)**2)
MSE_val_ennio_2 = np.mean((pred_test_ennio_2-label_val_general)**2)

print("MSE_train:", MSE_train_ennio_2)
print("MSE_val:", MSE_val_ennio_2)
# Out:
# MSE_train: 0.005088467107712645
# MSE_val: 0.00494103849670818

# %% [markdown]
# ### Ecobee SmartThermostat

# %%
pred_train_ecobee = ecobee_thermostat_model_1.predict(train_final_general).reshape(-1)
pred_test_ecobee = ecobee_thermostat_model_1.predict(val_general).reshape(-1)

MSE_train_ecobee = np.mean((pred_train_ecobee-label_train_final_general)**2)
MSE_val_ecobee = np.mean((pred_test_ecobee-label_val_general)**2)

print("MSE_train:", MSE_train_ecobee)
print("MSE_val:", MSE_val_ecobee)
# Out:
# MSE_train: 0.013443234377972482
# MSE_val: 0.012927179276407207

# %%
pred_train_ecobee_2 = ecobee_thermostat_model_2.predict(train_final_general).reshape(-1)
pred_test_ecobee_2 = ecobee_thermostat_model_2.predict(val_general).reshape(-1)

MSE_train_ecobee_2 = np.mean((pred_train_ecobee_2-label_train_final_general)**2)
MSE_val_ecobee_2 = np.mean((pred_test_ecobee_2-label_val_general)**2)

print("MSE_train:", MSE_train_ecobee_2)
print("MSE_val:", MSE_val_ecobee_2)
# Out:
# MSE_train: 0.005414795197714022
# MSE_val: 0.005202867237071319

# %% [markdown]
# ### Philips Baby Monitor

# %%
pred_train_philips = philips_baby_monitor_model_1.predict(train_final_general).reshape(-1)
pred_test_philips = philips_baby_monitor_model_1.predict(val_general).reshape(-1)

MSE_train_philips = np.mean((pred_train_philips-label_train_final_general)**2)
MSE_val_philips = np.mean((pred_test_philips-label_val_general)**2)

print("MSE_train:", MSE_train_philips)
print("MSE_val:", MSE_val_philips)
# Out:
# MSE_train: 0.0023527756469537142
# MSE_val: 0.002428155244094674

# %%
pred_train_philips_2 = philips_baby_monitor_model_2.predict(train_final_general).reshape(-1)
pred_test_philips_2 = philips_baby_monitor_model_2.predict(val_general).reshape(-1)

MSE_train_philips_2 = np.mean((pred_train_philips_2-label_train_final_general)**2)
MSE_val_philips_2 = np.mean((pred_test_philips_2-label_val_general)**2)

print("MSE_train:", MSE_train_philips_2)
print("MSE_val:", MSE_val_philips_2)
# Out:
# MSE_train: 0.00524922442016162
# MSE_val: 0.005110283693753519

# %%
#Provision 737
print('Provision 737_1:', MSE_val_provision_737)
print('Provision 737_2:', MSE_val_provision_737_2)
#Provision 838
print('Provision 838_1:', MSE_val_provision_838)
print('Provision 838_2:', MSE_val_provision_838_2)
#SimpleHome 1002
print('SimpleHome_1002_1:', MSE_val_simplehome_1002)
print('SimpleHome_1002_2:', MSE_val_simplehome_1002_2)
#SimpleHome 1003
print('SimpleHome_1003_1:', MSE_val_simplehome_1003)
print('SimpleHome_1003_2:', MSE_val_simplehome_1003_2)
#Danmini Doorbell
print('Danmini_1:', MSE_val_danmini)
print('Danmini_2:', MSE_val_danmini_2)
#Ennio Doorbell
print('Ennio_1:', MSE_val_ennio)
print('Ennio_2:', MSE_val_ennio_2)
#Ecobee Thermostat
print('Ecobee_1:', MSE_val_ecobee)
print('Ecobee_2:', MSE_val_ecobee_2)
#Philips Baby Monitor
print('Philips_1:', MSE_val_philips)
print('Philips_2:', MSE_val_philips_2)
# Out:
# Provision 737_1: 0.0036738563117005253
# Provision 737_2: 0.003854582154575655
# Provision 838_1: 0.003887114632422493
# Provision 838_2: 0.004079701985292209
# SimpleHome_1002_1: 0.012280873235525989
# SimpleHome_1002_2: 0.0021846602595447877
# SimpleHome_1003_1: 0.019046291597112987
# SimpleHome_1003_2: 0.01819769958560781
# Danmini_1: 0.015350598722230087
# Danmini_2: 0.015986871333328136
# Ennio_1: 0.01898285498194691
# Ennio_2: 0.00494103849670818
# Ecobee_1: 0.012927179276407207
# Ecobee_2: 0.005202867237071319
# Philips_1: 0.002428155244094674
# Philips_2: 0.005110283693753519

# %% [markdown]
# ### Model Performance - Generalized Data Set

# %% [markdown]
# |Rank | Model Name | MSE Test |
# |------|------|------|
# | 1 | SimpleHome 1002 Security Camera - Dropout Model| 0.00218 |
# | 2 | Philips Baby Monitor - Initial Model | 0.00242 |
# | 3 | Provision 737E Security Camera - Initial Model  | 0.00367 |
# | 4 | Provision 737E Security Camera - Dropout Model | 0.00385  |
# | 5 | Provision 838 Security Camera - Initial Model | 0.00389 |
# | 6 | Provision 838 Security Camera - Dropout Model | 0.00408 |
# | 7 | Ennio Doorbell - Dropout Model | 0.00494 |
# | 8 | Philips Baby Monitor - Dropout Model | 0.00511 |
# | 9 | Ecobee Thermostat - Dropout Model | 0.00520 |
# | 10 | SimpleHome 1002 Security Camera - Initial Model | 0.01228 |
# | 11 | Ecobee Thermostat - Initial Model | 0.01293 |
# | 12 | Danmini Doorbell - Initial Model| 0.01535 |
# | 13 | Danmini Doorbell - Dropout Model| 0.01599 |
# | 14 | Ennio Doorbell - Initial Model | 0.01898 |
# | 15 | Simple Home 1003 Security Camera - Dropout Model| 0.01820  |
# | 16 | Simple Home 1003 Security Camera - Initial Model| 0.01905 |

# %% [markdown]
# #### Model Performance Analysis
# <br>
# The dropout regularization model for the SimpleHome 1002 Wi-Fi Security Camera Dropout Model performed the best of the 16 models that were tested with the combined data set resulting in the smallest MSE of 0.00218.
#
# My goal was to create a neural network-based model that could accurately predict malicious botnet attacks on IoT devices. The above assessment tested each of the models that I created based on training data partitioned from individual device network events. However, in order to create a more universal detection system, a model needs to be able to perform well (classify with high levels of accuracy) while being fed generalized IoT device data. The application of such a model would be more valuable to an enterprise seeking to protect its extended perimeter from advanced malware attacks. Of the models that I created, the Simple Home 1002 Wi-Fi Security Camera Dropout Model minimized the loss calculated comparing actual data with predictuons.

# %% [markdown]
# # iNterpretting the Data

# %% [markdown]
# I began this project with the intention of creating a neural network based detection model to accurately detect botnet attacks using IoT devices in real-time. The models' results demonstrate that I was successful in my endeavor and experienced tremendous accuracy in classifying benign or normal events versus malicious attack based events.

# %% [markdown]
# | Rank | Device Name | Iteration 1 Accuracy | Iteration 1 Loss | Iteration 2 Accuracy | Iteration 2 Loss |
# |------|------|------|------|------|------|
# | 1 | Ecobee Thermostat | 99.92% | 0.0044  | 99.81% | 0.0139 |
# | 2 | Philips Baby Monitor | 99.91% | 0.0044  | 99.80%  | 0.0141 |
# | 3 | Provision 838 Security Camera | 99.91% | 0.0051  | 99.79% | 0.0152 |
# | 4 | Simple Home 1003 Security Camera | 99.90% | 0.0059  | 99.78% | 0.0112 |
# | 5 | Provision 738E Security Camera  | 99.88% | 0.0072  | 99.77%  | 0.0170 |
# | 6 | Danmini Doorbell | 99.88% | 0.0038  | 99.77%  | 0.0149 |
# | 7 | SimpleHome 1002 Security Camera | 99.87%  | 0.0052  | 99.73% | 0.0134 |
# | 8 | Ennio Doorbell  | 99.77% | 0.0128  | 99.81% | 0.0142 |

# %% [markdown]
# There is an overall small margin of error between the best performing model and the worst performing model. For that reason, I hesitate to label any of the models as "bad" or the "worst" because all resulted in better than 99% accuracy.
#
# The Ecobee Thermostat data based models produced the highest levels of accuracy:
# - Model 1: 99.92% accuracy
# - Model 2: 99.81% accuracy
#
# While the first Ennio Doorbell data based model produced the lowest level of accuracy, but still resulted in 99.77% accuracy.
#
# I am not concerned with overfitting or the narrow application of these models because I also tested them against a generalized combined dataset of all 8 devices to see how they would perform.

# %% [markdown]
# |Rank | Model Name | MSE Test |
# |------|------|------|
# | 1 | SimpleHome 1002 Security Camera - Dropout Model| 0.00218 |
# | 2 | Philips Baby Monitor - Initial Model | 0.00242 |
# | 3 | Provision 737E Security Camera - Initial Model  | 0.00367 |
# | 4 | Provision 737E Security Camera - Dropout Model | 0.00385  |
# | 5 | Provision 838 Security Camera - Initial Model | 0.00389 |
# | 6 | Provision 838 Security Camera - Dropout Model | 0.00408 |
# | 7 | Ennio Doorbell - Dropout Model | 0.00494 |
# | 8 | Philips Baby Monitor - Dropout Model | 0.00511 |
# | 9 | Ecobee Thermostat - Dropout Model | 0.00520 |
# | 10 | SimpleHome 1002 Security Camera - Initial Model | 0.01228 |
# | 11 | Ecobee Thermostat - Initial Model | 0.01293 |
# | 12 | Danmini Doorbell - Initial Model| 0.01535 |
# | 13 | Danmini Doorbell - Dropout Model| 0.01599 |
# | 14 | Ennio Doorbell - Initial Model | 0.01898 |
# | 15 | Simple Home 1003 Security Camera - Dropout Model| 0.01820  |
# | 16 | Simple Home 1003 Security Camera - Initial Model| 0.01905 |

# %% [markdown]
# All 16 models returned minimal MSE loss values which confirms their effectiveness in detecting Mirai and BASHLITE based botnet attacks.

# %% [markdown]
# # Summary

# %% [markdown]
# This accurate detection of attacks in real-time can be combined with existing security solutions for a truly layered security approach. This valuable outputted data can be used to automate incident response to quickly mitigate risk to an enterprise or individual entity. Combined with a next-gen firewall, antivirus software, device management strategy, and IDS/IPS monitoring - this detection solution will better protect IoT devices and all of our valuable data.

# %% [markdown]
# ## Post-Completion Model Testing and Experimentation

# %%
x = provision_737_1.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
provision_737_1_scaled = pd.DataFrame(x_scaled)

# %%
X = provision_737_1_scaled
y = provision_737_2["Benign/Attack"].as_matrix().T

# %%
X_resample, y_resample = SMOTE().fit_sample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resample, y_resample, test_size=0.2, random_state=0)

# %%
train_final_provision_X_1 = X_train[:389944]
label_train_final_provision_X_1 = y_train[:389944]

val_provision_X_1 = X_test[97486:]
label_val_provision_X_1 = y_test[97486:]

print("Train:", np.shape(train_final_provision_X_1))
print("Validation:", np.shape(val_provision_X_1))
print("Label Validation:", np.shape(label_val_provision_X_1))
print("Label Train Final:", np.shape(label_train_final_provision_X_1))
# Out:
# Train: (389944, 115)
# Validation: (97487, 115)
# Label Validation: (97487,)
# Label Train Final: (389944,)

# %% [markdown]
# ### Adding hidden layers and neurons

# %%
model_provision_X_1 = models.Sequential()
model_provision_X_1.add(layers.Dense(75, activation='relu', input_shape=(115,)))
model_provision_X_1.add(layers.Dense(50, activation='relu'))
model_provision_X_1.add(layers.Dense(25, activation='relu'))
model_provision_X_1.add(layers.Dense(1, activation='sigmoid'))

# %%
model_provision_X_1.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model_val = model_provision_X_1.fit(train_final_provision_X_1,
                    label_train_final_provision_X_1,
                    epochs=100,
                    batch_size=256,
                    validation_data=(val_provision_X_1, label_val_provision_X_1))
# Out:
# Train on 389944 samples, validate on 97487 samples
# Epoch 1/100
# 389944/389944 [==============================] - 9s 23us/step - loss: 0.1254 - acc: 0.9840 - val_loss: 0.0219 - val_acc: 0.9953
# Epoch 2/100
# 389944/389944 [==============================] - 4s 10us/step - loss: 0.0170 - acc: 0.9961 - val_loss: 0.0163 - val_acc: 0.9962
# Epoch 3/100
# 389944/389944 [==============================] - 4s 9us/step - loss: 0.0137 - acc: 0.9967 - val_loss: 0.0141 - val_acc: 0.9966
# Epoch 4/100
# 389944/389944 [==============================] - 4s 9us/step - loss: 0.0118 - acc: 0.9972 - val_loss: 0.0125 - val_acc: 0.9972
# Epoch 5/100
# 389944/389944 [==============================] - 4s 9us/step - loss: 0.0105 - acc: 0.9977 - val_loss: 0.0115 - val_acc: 0.9977
# Epoch 6/100
# 389944/389944 [==============================] - 4s 10us/step - loss: 0.0095 - acc: 0.9980 - val_loss: 0.0107 - val_acc: 0.9980
# Epoch 7/100
# ...

# %% [markdown]
# ### Analysis
# <br>
# Adding an additional Hidden Layer to our model with 50 neurons, upping our input layer to 75 neurons, and increasing our epochs to 100 resulted in 99.91% accuracy. However, the model's active learning rate plateaued after epoch 15 (maybe even earlier) which means that the remaining compute cycles were not well spent to increase an additional 0.02%. This added time does not deliver significant value. This confirms my initial assessment and approach with my first models on the Provision PT 737 Security Camera data. The added complexity does not deliver.

# %% [markdown]
# ### Experimenting with Activation Functions

# %%
model_provision_X_2 = models.Sequential()
model_provision_X_2.add(layers.Dense(50, activation='tanh', input_shape=(115,)))
model_provision_X_2.add(layers.Dense(25, activation='tanh'))
model_provision_X_2.add(layers.Dense(1, activation='sigmoid'))

# %%
model_provision_X_2.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model_val = model_provision_X_2.fit(train_final_provision_X_1,
                    label_train_final_provision_X_1,
                    epochs=50,
                    batch_size=256,
                    validation_data=(val_provision_X_1, label_val_provision_X_1))
# Out:
# Train on 389944 samples, validate on 97487 samples
# Epoch 1/50
# 389944/389944 [==============================] - 4s 11us/step - loss: 0.0967 - acc: 0.9870 - val_loss: 0.0273 - val_acc: 0.9951
# Epoch 2/50
# 389944/389944 [==============================] - 3s 8us/step - loss: 0.0215 - acc: 0.9956 - val_loss: 0.0201 - val_acc: 0.9956
# Epoch 3/50
# 389944/389944 [==============================] - 3s 8us/step - loss: 0.0174 - acc: 0.9961 - val_loss: 0.0177 - val_acc: 0.9961
# Epoch 4/50
# 389944/389944 [==============================] - 4s 11us/step - loss: 0.0155 - acc: 0.9965 - val_loss: 0.0162 - val_acc: 0.9965
# Epoch 5/50
# 389944/389944 [==============================] - 4s 9us/step - loss: 0.0142 - acc: 0.9968 - val_loss: 0.0149 - val_acc: 0.9967
# Epoch 6/50
# 389944/389944 [==============================] - 3s 9us/step - loss: 0.0130 - acc: 0.9971 - val_loss: 0.0139 - val_acc: 0.9970
# Epoch 7/50
# ...

# %% [markdown]
# ### Analysis
# <br>
# Changing the chosen activation functions for our input and hidden layers from relu to tanh resulted in 99.89% accuracy. Again we see the model's active learning rate plateauing after around epoch 19 which means that the remaining compute cycles were not well spent to increase an additional 0.01%. This experiement confirms that my decision to implement the Rectified Linear Unit activation function was wise.
